# %% [markdown]
# # Project Goal:
# - Import production and permit data for company and create custom fields requested by CEO
# - Add geographic fields to be used with Tableau

# %% [markdown]
# ## Read in Libraries and Data

# %%
import pandas as pd
import numpy as np
import geopandas as gp
import requests as req
import re

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('precision', 2)

# %%
permits = pd.read_csv("Raw Data/DI Magnum NewDrill Permits.CSV")
prod = pd.read_csv("Raw Data/Production Table.CSV")
counties = gp.read_file("zip://Raw Data/UScounties.zip")

# %% [markdown]
# ## Clean Up Production DataFrame

# %%
prod.head()
prod["Producing Status"].value_counts()
# Out:
#           API/UWI Operator Alias (Legacy) Well/Lease Name Well Number  \
# 0  42469344440000    MAGNUM PRODUCING, LP     SPACEK UNIT           1
# 1  42245328640000    MAGNUM PRODUCING, LP   MCLEAN UNIT 4           4
# 2  42039333450000    MAGNUM PRODUCING, LP          DUCROZ           1
# 3  42321324010000    MAGNUM PRODUCING, LP        ANDERSON           3
# 4               0    MAGNUM PRODUCING, LP   LA LUW 801958         NaN
#
#     County/Parish                 Reservoir Production Type Producing Status  \
# 0   VICTORIA (TX)             MIDDLE WILCOX             GAS         INACTIVE
# 1  JEFFERSON (TX)  HETEROSTEGINA - DISPOSAL             OIL           ACTIVE
# 2   BRAZORIA (TX)               TOP OF FRIO             OIL         INACTIVE
# 3  MATAGORDA (TX)                   HUEBNER             OIL           ACTIVE
# 4      (N/A) (LA)                       NaN             OIL         INACTIVE
#
#   Drill Type  Measured Depth (TD)  ... Block OCS Area PGC Area  \
# 0          V               9500.0  ...   NaN      NaN    P-330
# 1          V               8560.0  ...   NaN      NaN    P-330
# 2          V              11100.0  ...   NaN      NaN    P-330
# 3          D              10600.0  ...   NaN      NaN    P-330
# 4          U                  NaN  ...   NaN      NaN      NaN
#
#       Operator (Reported)       Survey  Entity ID  Last 12 Oil  Last 12 Gas  \
# 0    MAGNUM PRODUCING, LP     HINES, D  130836314          NaN          NaN
# 1    MAGNUM PRODUCING, LP  EL&RR RR CO  130833332      10822.0          NaN
# 2    MAGNUM PRODUCING, LP   DILLARD, N  130819038          NaN          NaN
# 3    MAGNUM PRODUCING, LP      HALL, E  130785484        857.0      19409.0
# 4  MAGNUM PRODUCING, L.P.          NaN  130769684        119.0          NaN
#
#    Last 12 Water  Other No.
# 0            NaN          0
# 1            0.0          0
# 2            NaN          0
# 3          171.0          0
# 4            0.0     801958
#
# [5 rows x 89 columns]
# INACTIVE                                  501
# P & A                                     149
# ACTIVE                                     65
# WORKED OVER TO ANOTHER ZONE                52
# TA                                         16
# RECLASSIFIED TO ANOTHER TYPE OF ENTITY     10
# ACTIVE INJ                                  9
# CANCELLED                                   5
# PERMIT                                      3
# SHUT IN                                     1
# APPLICATION FOR PERMIT TO DRILL             1
# Name: Producing Status, dtype: int64

# %% [markdown]
# ### Remove P&A Wells and API Trailing 0's

# %%
#filtering out wells that have already been P&A by magnum
prod = prod.loc[prod["Producing Status"]!='P & A']

prod["Producing Status"].value_counts()
# Out:
# INACTIVE                                  501
# ACTIVE                                     65
# WORKED OVER TO ANOTHER ZONE                52
# TA                                         16
# RECLASSIFIED TO ANOTHER TYPE OF ENTITY     10
# ACTIVE INJ                                  9
# CANCELLED                                   5
# PERMIT                                      3
# SHUT IN                                     1
# APPLICATION FOR PERMIT TO DRILL             1
# Name: Producing Status, dtype: int64

# %%
#testing to see if api number can be cleaned by dividing number by 10,000 to remove trailing 0's
test = prod["API/UWI"].iloc[0]

test

int(test/(10**4))
# Out:
# 42469344440000
# 4246934444

# %%
#dividing each api by 10,000 to clean number and remove trailing 0's
prod["API/UWI"] = prod["API/UWI"].apply(lambda x: int(x/(10**4)))

# %%
prod.head()
# Out:
#       API/UWI Operator Alias (Legacy) Well/Lease Name Well Number  \
# 0  4246934444    MAGNUM PRODUCING, LP     SPACEK UNIT           1
# 1  4224532864    MAGNUM PRODUCING, LP   MCLEAN UNIT 4           4
# 2  4203933345    MAGNUM PRODUCING, LP          DUCROZ           1
# 3  4232132401    MAGNUM PRODUCING, LP        ANDERSON           3
# 4           0    MAGNUM PRODUCING, LP   LA LUW 801958         NaN
#
#     County/Parish                 Reservoir Production Type Producing Status  \
# 0   VICTORIA (TX)             MIDDLE WILCOX             GAS         INACTIVE
# 1  JEFFERSON (TX)  HETEROSTEGINA - DISPOSAL             OIL           ACTIVE
# 2   BRAZORIA (TX)               TOP OF FRIO             OIL         INACTIVE
# 3  MATAGORDA (TX)                   HUEBNER             OIL           ACTIVE
# 4      (N/A) (LA)                       NaN             OIL         INACTIVE
#
#   Drill Type  Measured Depth (TD)  ... Block OCS Area PGC Area  \
# 0          V               9500.0  ...   NaN      NaN    P-330
# 1          V               8560.0  ...   NaN      NaN    P-330
# 2          V              11100.0  ...   NaN      NaN    P-330
# 3          D              10600.0  ...   NaN      NaN    P-330
# 4          U                  NaN  ...   NaN      NaN      NaN
#
#       Operator (Reported)       Survey  Entity ID  Last 12 Oil  Last 12 Gas  \
# 0    MAGNUM PRODUCING, LP     HINES, D  130836314          NaN          NaN
# 1    MAGNUM PRODUCING, LP  EL&RR RR CO  130833332      10822.0          NaN
# 2    MAGNUM PRODUCING, LP   DILLARD, N  130819038          NaN          NaN
# 3    MAGNUM PRODUCING, LP      HALL, E  130785484        857.0      19409.0
# 4  MAGNUM PRODUCING, L.P.          NaN  130769684        119.0          NaN
#
#    Last 12 Water  Other No.
# 0            NaN          0
# 1            0.0          0
# 2            NaN          0
# 3          171.0          0
# 4            0.0     801958
#
# [5 rows x 89 columns]

# %% [markdown]
# ### Create Cleaned County Column
# * cleaned county column only has name and no state appended at the end

# %%
#clean county names | using test row to test logic
prod["County/Parish"].iloc[197][:-5]

prod["Cleaned County"] = prod["County/Parish"].apply(lambda x: x[:-5])
# Out:
# 'AUSTIN'

# %%
prod.head()
# Out:
#       API/UWI Operator Alias (Legacy) Well/Lease Name Well Number  \
# 0  4246934444    MAGNUM PRODUCING, LP     SPACEK UNIT           1
# 1  4224532864    MAGNUM PRODUCING, LP   MCLEAN UNIT 4           4
# 2  4203933345    MAGNUM PRODUCING, LP          DUCROZ           1
# 3  4232132401    MAGNUM PRODUCING, LP        ANDERSON           3
# 4           0    MAGNUM PRODUCING, LP   LA LUW 801958         NaN
#
#     County/Parish                 Reservoir Production Type Producing Status  \
# 0   VICTORIA (TX)             MIDDLE WILCOX             GAS         INACTIVE
# 1  JEFFERSON (TX)  HETEROSTEGINA - DISPOSAL             OIL           ACTIVE
# 2   BRAZORIA (TX)               TOP OF FRIO             OIL         INACTIVE
# 3  MATAGORDA (TX)                   HUEBNER             OIL           ACTIVE
# 4      (N/A) (LA)                       NaN             OIL         INACTIVE
#
#   Drill Type  Measured Depth (TD)  ... OCS Area PGC Area  \
# 0          V               9500.0  ...      NaN    P-330
# 1          V               8560.0  ...      NaN    P-330
# 2          V              11100.0  ...      NaN    P-330
# 3          D              10600.0  ...      NaN    P-330
# 4          U                  NaN  ...      NaN      NaN
#
#       Operator (Reported)       Survey  Entity ID  Last 12 Oil  Last 12 Gas  \
# 0    MAGNUM PRODUCING, LP     HINES, D  130836314          NaN          NaN
# 1    MAGNUM PRODUCING, LP  EL&RR RR CO  130833332      10822.0          NaN
# 2    MAGNUM PRODUCING, LP   DILLARD, N  130819038          NaN          NaN
# 3    MAGNUM PRODUCING, LP      HALL, E  130785484        857.0      19409.0
# 4  MAGNUM PRODUCING, L.P.          NaN  130769684        119.0          NaN
#
#    Last 12 Water  Other No.  Cleaned County
# 0            NaN          0        VICTORIA
# 1            0.0          0       JEFFERSON
# 2            NaN          0        BRAZORIA
# 3          171.0          0       MATAGORDA
# 4            0.0     801958           (N/A)
#
# [5 rows x 90 columns]

# %% [markdown]
# ### Adding Latest BOE/month column

# %%
prod["Latest BOE"] = (prod["Latest Gas"]/6) + prod["Latest Oil"]

# %% [markdown]
# ## Permits Table

# %%
permits.head()
# Out:
#    API 10/UWI District  Filed Date Approved Date Expired Date State/Province  \
# 0  3000564345       SE         NaN    2019-12-13   2021-12-02             NM
# 1  4245730898        3  2019-10-03    2019-10-08   2021-10-08             TX
# 2  4203933345        3  2019-07-03    2019-07-05   2021-07-05             TX
# 3  4232132426        3  2019-06-25    2019-06-26   2021-06-26             TX
# 4  4246934444        2  2019-05-23    2019-05-24   2021-05-24             TX
#
#     County/Parish Operator Alias (Legacy)         Lease Name Well Number  ...  \
# 0     CHAVES (NM)             MAGNUM PROD  THE PEGGY FEDERAL         113  ...
# 1      TYLER (TX)             MAGNUM PROD        BIG THICKET           1  ...
# 2   BRAZORIA (TX)             MAGNUM PROD             DUCROZ           1  ...
# 3  MATAGORDA (TX)             MAGNUM PROD              TRULL           1  ...
# 4   VICTORIA (TX)             MAGNUM PROD        SPACEK UNIT           1  ...
#
#   Bottom Hole Latitude (WGS84)  Bottom Hole Longitude (WGS84)  Lease Number  \
# 0                        33.54                        -104.14        326731
# 1                        30.56                         -94.34           NaN
# 2                        28.90                         -95.60         27788
# 3                        28.77                         -96.26           NaN
# 4                        29.08                         -96.98        290069
#
#   Permit Depth UOM Permit Number            DI Basin          DI Play  \
# 0               ft  TEMP86977488     NORTHWEST SHELF  NORTHWEST SHELF
# 1               ft        857731  GULF COAST CENTRAL              NaN
# 2               ft        854812  GULF COAST CENTRAL              NaN
# 3               ft        854558  GULF COAST CENTRAL              NaN
# 4               ft        853438     GULF COAST WEST              NaN
#
#   DI Subplay Operator Company Name Operator Ticker
# 0        NaN  MAGNUM PRODUCING, LP             NaN
# 1        NaN  MAGNUM PRODUCING, LP             NaN
# 2        NaN  MAGNUM PRODUCING, LP             NaN
# 3        NaN  MAGNUM PRODUCING, LP             NaN
# 4        NaN  MAGNUM PRODUCING, LP             NaN
#
# [5 rows x 51 columns]

# %%
#finding which wells in production tables exist in the new drill permits table by magnum
prod["API/UWI"].isin(permits["API 10/UWI"]).head(10)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: API/UWI, dtype: bool

# %% [markdown]
# ### Creating Column to Track Which Wells were Drilled By Magnum
# * formula will check if api number exists in the newdrill permits data table

# %%
#creating new column representing whether or not well in production table exists
prod["Magnum Drilled (Y/N)"] = prod["API/UWI"].isin(permits["API 10/UWI"])

# %%
#mapping truths and falses to yes or no
prod["Magnum Drilled (Y/N)"] = prod["Magnum Drilled (Y/N)"].map({True: "Y", False: "N"})

# %%
#looking at how many wells are marked yes versus length of the entire permits table
prod["Magnum Drilled (Y/N)"].value_counts()


prod["Magnum Drilled (Y/N)"].value_counts()['Y']
len(permits)

print("There are {} permits not found in new drill permits table".format(len(permits)- prod["Magnum Drilled (Y/N)"].value_counts()['Y']))
# Out:
# N    542
# Y    121
# Name: Magnum Drilled (Y/N), dtype: int64
# 121
# 198
# There are 77 permits not found in new drill permits table

# %% [markdown]
# ## Counties Shapefile Cleanup

# %%
counties.head()
# Out:
#                 NAME  STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  \
# 0  Lake of the Woods   Minnesota         27       077  27077
# 1              Ferry  Washington         53       019  53019
# 2            Stevens  Washington         53       065  53065
# 3           Okanogan  Washington         53       047  53047
# 4       Pend Oreille  Washington         53       051  53051
#
#                                             geometry
# 0  POLYGON ((-95.34283 48.54668, -95.34105 48.715...
# 1  POLYGON ((-118.85163 47.94956, -118.84846 48.4...
# 2  POLYGON ((-117.43883 48.04412, -117.54219 48.0...
# 3  POLYGON ((-118.97209 47.93915, -118.97406 47.9...
# 4  POLYGON ((-117.43858 48.99992, -117.03205 48.9...

# %%
len(counties)
counties["FIPS"].nunique()
# Out:
# 3141
# 3141

# %% [markdown]
# ### Reading in States Table Online with Postal Codes to Add to Counties Shapefile

# %%
stlink = 'https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013696'
stTable = pd.read_html(req.get(stlink).content)[0]

# %%
stTable.head()
# Out:
#          Name Postal Code  FIPS
# 0     Alabama          AL   1.0
# 1      Alaska          AK   2.0
# 2     Arizona          AZ   4.0
# 3    Arkansas          AR   5.0
# 4  California          CA   6.0

# %% [markdown]
# ### Joining Counties Shapefile with State Postal Codes and Cleaning up Duplicate Columns

# %%
counties = pd.merge(counties, stTable[["Name", "Postal Code"]], how = "left", left_on="STATE_NAME", right_on="Name")

# %%
counties.drop(columns = "Name", inplace=True)

# %%
counties.head()
# Out:
#                 NAME  STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  \
# 0  Lake of the Woods   Minnesota         27       077  27077
# 1              Ferry  Washington         53       019  53019
# 2            Stevens  Washington         53       065  53065
# 3           Okanogan  Washington         53       047  53047
# 4       Pend Oreille  Washington         53       051  53051
#
#                                             geometry Postal Code
# 0  POLYGON ((-95.34283 48.54668, -95.34105 48.715...          MN
# 1  POLYGON ((-118.85163 47.94956, -118.84846 48.4...          WA
# 2  POLYGON ((-117.43883 48.04412, -117.54219 48.0...          WA
# 3  POLYGON ((-118.97209 47.93915, -118.97406 47.9...          WA
# 4  POLYGON ((-117.43858 48.99992, -117.03205 48.9...          WA

# %% [markdown]
# ### Cleaning County Names by Converting to UpperCase for Matching/Joining as a Primary Key

# %%
counties["NAME"] = counties["NAME"].apply(lambda x: x.upper())

# %%
counties[["Postal Code", "NAME", "FIPS"]]
# Out:
#      Postal Code                             NAME   FIPS
# 0             MN                LAKE OF THE WOODS  27077
# 1             WA                            FERRY  53019
# 2             WA                          STEVENS  53065
# 3             WA                         OKANOGAN  53047
# 4             WA                     PEND OREILLE  53051
# 5             ID                         BOUNDARY  16021
# 6             MT                          LINCOLN  30053
# 7             MT                         FLATHEAD  30029
# 8             MT                          GLACIER  30035
# 9             MT                            TOOLE  30101
# 10            MT                          LIBERTY  30051
# 11            MT                             HILL  30041
# 12            MT                         SHERIDAN  30091
# 13            ND                           DIVIDE  38023
# 14            ND                            BURKE  38013
# 15            ND                         RENVILLE  38075
# 16            ND                        BOTTINEAU  38009
# 17            ND                          ROLETTE  38079
# 18            ND                           TOWNER  38095
# 19            ND                         CAVALIER  38019
# 20            ND                          PEMBINA  38067
# 21            MN                          KITTSON  27069
# 22            MN                           ROSEAU  27135
# 23            MT                           BLAINE  30005
# 24            MT                         PHILLIPS  30071
# 25            MT                           VALLEY  30105
# 26            MT                          DANIELS  30019
# 27            WA                          WHATCOM  53073
# 28            ID                           BONNER  16017
# 29            ND                             WARD  38101
# ...          ...                              ...    ...
# 3111          AK                MATANUSKA-SUSITNA  02170
# 3112          AK                     WADE HAMPTON  02270
# 3113          AK                           BETHEL  02050
# 3114          AK                        ANCHORAGE  02020
# 3115          AK                  KENAI PENINSULA  02122
# 3116          AK                       DILLINGHAM  02070
# 3117          AK               LAKE AND PENINSULA  02164
# 3118          AK                           HAINES  02100
# 3119          AK                           JUNEAU  02110
# 3120          AK                    KODIAK ISLAND  02150
# 3121          AK                            SITKA  02220
# 3122          AK              WRANGELL-PETERSBURG  02280
# 3123          AK                KETCHIKAN GATEWAY  02130
# 3124          AK  PRINCE OF WALES-OUTER KETCHIKAN  02201
# 3125          AK                   ALEUTIANS EAST  02013
# 3126          AK                   ALEUTIANS WEST  02016
# 3127          HI                          KALAWAO  15005
# 3128          HI                            KAUAI  15007
# 3129          HI                         HONOLULU  15003
# 3130          HI                             MAUI  15009
# 3131          HI                           HAWAII  15001
# 3132          VA                     PITTSYLVANIA  51143
# 3133          VA                         DANVILLE  51590
# 3134          AK                   VALDEZ-CORDOVA  02261
# 3135          AK                          YAKUTAT  02282
# 3136          AK            SKAGWAY-HOONAH-ANGOON  02232
# 3137          AK                    YUKON-KOYUKUK  02290
# 3138          AK              SOUTHEAST FAIRBANKS  02240
# 3139          AK                           DENALI  02068
# 3140          CO                       BROOMFIELD  08014
#
# [3141 rows x 3 columns]

# %%
prod.head(1)
# Out:
#       API/UWI Operator Alias (Legacy) Well/Lease Name Well Number  \
# 0  4246934444    MAGNUM PRODUCING, LP     SPACEK UNIT           1
#
#    County/Parish      Reservoir Production Type Producing Status Drill Type  \
# 0  VICTORIA (TX)  MIDDLE WILCOX             GAS         INACTIVE          V
#
#    Measured Depth (TD)  ...   Operator (Reported)    Survey  Entity ID  \
# 0               9500.0  ...  MAGNUM PRODUCING, LP  HINES, D  130836314
#
#    Last 12 Oil  Last 12 Gas  Last 12 Water  Other No.  Cleaned County  \
# 0          NaN          NaN            NaN          0        VICTORIA
#
#    Latest BOE  Magnum Drilled (Y/N)
# 0         NaN                     Y
#
# [1 rows x 92 columns]

# %% [markdown]
# ### Joining Production with Counties Data to Bring Over County FIPS Codes & Cleanup Duplicate Columns

# %%
prod = pd.merge(prod, counties[["Postal Code", "NAME", "FIPS"]], how = "left", left_on=["State", "Cleaned County"], right_on = ["Postal Code", "NAME"])

# %%
prod.drop(columns = ["Postal Code", "NAME"], inplace = True)

# %%
prod.head()
# Out:
#       API/UWI Operator Alias (Legacy) Well/Lease Name Well Number  \
# 0  4246934444    MAGNUM PRODUCING, LP     SPACEK UNIT           1
# 1  4224532864    MAGNUM PRODUCING, LP   MCLEAN UNIT 4           4
# 2  4203933345    MAGNUM PRODUCING, LP          DUCROZ           1
# 3  4232132401    MAGNUM PRODUCING, LP        ANDERSON           3
# 4           0    MAGNUM PRODUCING, LP   LA LUW 801958         NaN
#
#     County/Parish                 Reservoir Production Type Producing Status  \
# 0   VICTORIA (TX)             MIDDLE WILCOX             GAS         INACTIVE
# 1  JEFFERSON (TX)  HETEROSTEGINA - DISPOSAL             OIL           ACTIVE
# 2   BRAZORIA (TX)               TOP OF FRIO             OIL         INACTIVE
# 3  MATAGORDA (TX)                   HUEBNER             OIL           ACTIVE
# 4      (N/A) (LA)                       NaN             OIL         INACTIVE
#
#   Drill Type  Measured Depth (TD)  ...       Survey  Entity ID Last 12 Oil  \
# 0          V               9500.0  ...     HINES, D  130836314         NaN
# 1          V               8560.0  ...  EL&RR RR CO  130833332     10822.0
# 2          V              11100.0  ...   DILLARD, N  130819038         NaN
# 3          D              10600.0  ...      HALL, E  130785484       857.0
# 4          U                  NaN  ...          NaN  130769684       119.0
#
#    Last 12 Gas  Last 12 Water  Other No.  Cleaned County  Latest BOE  \
# 0          NaN            NaN          0        VICTORIA         NaN
# 1          NaN            0.0          0       JEFFERSON         NaN
# 2          NaN            NaN          0        BRAZORIA         NaN
# 3      19409.0          171.0          0       MATAGORDA         NaN
# 4          NaN            0.0     801958           (N/A)         NaN
#
#    Magnum Drilled (Y/N)   FIPS
# 0                     Y  48469
# 1                     Y  48245
# 2                     Y  48039
# 3                     Y  48321
# 4                     N    NaN
#
# [5 rows x 93 columns]

# %%
prod[prod["FIPS"].isna()]
# Out:
#      API/UWI Operator Alias (Legacy)    Well/Lease Name Well Number  \
# 4          0    MAGNUM PRODUCING, LP      LA LUW 801958         NaN
# 217        0    MAGNUM PRODUCING, LP  PAINTERS GAS UNIT         NaN
#
#     County/Parish Reservoir Production Type Producing Status Drill Type  \
# 4      (N/A) (LA)       NaN             OIL         INACTIVE          U
# 217  UNKNOWN (TX)     3-G-1             GAS         INACTIVE          V
#
#      Measured Depth (TD)  ... Survey  Entity ID Last 12 Oil  Last 12 Gas  \
# 4                    NaN  ...    NaN  130769684       119.0          NaN
# 217                  NaN  ...    NaN  105561337         NaN          NaN
#
#      Last 12 Water  Other No.  Cleaned County  Latest BOE  \
# 4              0.0     801958           (N/A)         NaN
# 217            NaN          0         UNKNOWN         NaN
#
#      Magnum Drilled (Y/N)  FIPS
# 4                       N   NaN
# 217                     N   NaN
#
# [2 rows x 93 columns]

# %%
pd.options.display.max_columns = len(prod.columns)
prod.head()
# Out:
#       API/UWI Operator Alias (Legacy) Well/Lease Name Well Number  \
# 0  4246934444    MAGNUM PRODUCING, LP     SPACEK UNIT           1
# 1  4224532864    MAGNUM PRODUCING, LP   MCLEAN UNIT 4           4
# 2  4203933345    MAGNUM PRODUCING, LP          DUCROZ           1
# 3  4232132401    MAGNUM PRODUCING, LP        ANDERSON           3
# 4           0    MAGNUM PRODUCING, LP   LA LUW 801958         NaN
#
#     County/Parish                 Reservoir Production Type Producing Status  \
# 0   VICTORIA (TX)             MIDDLE WILCOX             GAS         INACTIVE
# 1  JEFFERSON (TX)  HETEROSTEGINA - DISPOSAL             OIL           ACTIVE
# 2   BRAZORIA (TX)               TOP OF FRIO             OIL         INACTIVE
# 3  MATAGORDA (TX)                   HUEBNER             OIL           ACTIVE
# 4      (N/A) (LA)                       NaN             OIL         INACTIVE
#
#   Drill Type  Measured Depth (TD)   Spud Date First Prod Date Last Prod Date  \
# 0          V               9500.0  2019-06-19             NaN            NaN
# 1          V               8560.0  2018-05-08      2020-06-01     2020-12-01
# 2          V              11100.0  2019-10-16             NaN            NaN
# 3          D              10600.0  2017-03-08      2020-01-01     2020-10-01
# 4          U                  NaN         NaN      2010-11-01     2012-01-01
#
#    Months Produced  Cum Gas  Daily Gas  Cum Oil  Daily Oil  Latest Oil  \
# 0              NaN      NaN        NaN      NaN        NaN         NaN
# 1              7.0      NaN        NaN  10822.0       51.0      1566.0
# 2              NaN      NaN        NaN      NaN        NaN         NaN
# 3              7.0  19409.0       89.0    857.0        4.0         2.0
# 4              2.0      NaN        NaN    322.0        NaN       119.0
#
#    Latest Gas  Cum Water  Cum BOE DI Subplay  First Month Oil  \
# 0         NaN        NaN      NaN        NaN              NaN
# 1         NaN        0.0  10822.0        NaN           1618.0
# 2         NaN        NaN      NaN        NaN              NaN
# 3         NaN      171.0   4092.0        NaN            197.0
# 4         NaN        0.0    322.0        NaN            203.0
#
#    First Month Gas  First 6 Oil            DI Basin  First 6 Gas  First 6 BOE  \
# 0              NaN          NaN     GULF COAST WEST          NaN          NaN
# 1              NaN       9256.0  GULF COAST CENTRAL          0.0       9256.0
# 2              NaN          NaN  GULF COAST CENTRAL          NaN          NaN
# 3           3206.0        687.0  GULF COAST CENTRAL      19409.0       3922.0
# 4              NaN        203.0                 NaN          0.0        203.0
#
#    First 6 Water DI Play  Prac IP Oil Daily  Prac IP BOE  Prac IP Gas Daily  \
# 0            NaN     NaN                NaN          NaN                NaN
# 1            0.0     NaN               59.0         59.0                0.0
# 2            NaN     NaN                NaN          NaN                NaN
# 3          138.0     NaN                7.0         33.0              159.0
# 4            0.0     NaN                4.0          4.0                0.0
#
#    Prac IP CFGED  Latest Water  Prior 12 Oil  Prior 12 Gas Last Test Date  \
# 0            NaN           NaN           NaN           NaN     2020-11-19
# 1       353806.0           0.0           NaN           NaN     2020-10-27
# 2            NaN           NaN           NaN           NaN            NaN
# 3       198448.0           0.0           NaN           NaN     2020-01-22
# 4        23032.0           0.0         203.0           NaN            NaN
#
#    Prior 12 Water  Last Flow Pressure  Last WHSIP  2nd Month GOR  Latest GOR  \
# 0             NaN              3451.0      4600.0            NaN         NaN
# 1             NaN                 NaN         NaN            0.0         NaN
# 2             NaN                 NaN         NaN            NaN         NaN
# 3             NaN                 NaN         NaN        23820.0    22647.61
# 4             0.0                 NaN         NaN            NaN         NaN
#
#    Cum GOR  Last 12 Yield  2nd Month Yield  Latest Yield  Peak Gas  \
# 0      NaN            NaN              NaN           NaN       NaN
# 1      0.0            NaN              NaN           NaN       NaN
# 2      NaN            NaN              NaN           NaN       NaN
# 3  22650.0          44.16             42.0           NaN    6151.0
# 4      0.0            NaN              0.0           NaN       NaN
#
#    Peak Gas Month No.  Peak Oil  Peak Oil Month No.  Peak BOE  \
# 0                 NaN       NaN                 NaN       NaN
# 1                 NaN    1828.0                 2.0    1828.0
# 2                 NaN       NaN                 NaN       NaN
# 3                 4.0     197.0                 1.0    1169.0
# 4                 NaN     203.0                 1.0     203.0
#
#    Peak BOE Month No.  Peak MMCFGE  Peak MMCFGE Month No.  Upper Perforation  \
# 0                 NaN          NaN                    NaN             9270.0
# 1                 2.0         11.0                    2.0             5961.0
# 2                 NaN          NaN                    NaN                NaN
# 3                 4.0          7.0                    4.0             8781.0
# 4                 1.0          1.0                    1.0                NaN
#
#    Lower Perforation  Gas Gravity  Oil Gravity Completion Date  Well Count  \
# 0             9312.0         0.66         46.0      2020-02-23           1
# 1             6044.0          NaN         30.5      2019-06-29           1
# 2                NaN          NaN          NaN      2019-11-11           1
# 3             8950.0          NaN         40.0      2020-01-09           1
# 4                NaN          NaN          NaN             NaN           1
#
#    Max Active Wells                     Gas Gatherer  \
# 0               NaN             MAGNUM PRODUCING, LP
# 1               1.0             MAGNUM PRODUCING, LP
# 2               NaN                              NaN
# 3               1.0             MAGNUM PRODUCING, LP
# 4               1.0  GULF SOUTH PIPELINE COMPANY, LP
#
#                 Oil Gatherer Lease Number  Gross Perforated Interval  \
# 0      GULFMARK ENERGY, INC.       290069                       42.0
# 1      GULFMARK ENERGY, INC.        27819                       83.0
# 2                        NaN        27788                        NaN
# 3      GULFMARK ENERGY, INC.        27736                      169.0
# 4  L & L TRANSPORTATION, LLC          NaN                        NaN
#
#    True Vertical Depth              Field State District  \
# 0                  NaN       HELEN GOHLKE    TX       02
# 1                  NaN           BIG HILL    TX       03
# 2                  NaN            WILDCAT    TX       03
# 3                  NaN        LUCKY, EAST    TX       03
# 4                  NaN  OAKLEY, NORTHWEST    LA      NaN
#
#                AAPG Geologic Province Section Country Township Range  \
# 0  TEXAS & LOUISIANA GULF COAST BASIN     NaN     USA      NaN   NaN
# 1  TEXAS & LOUISIANA GULF COAST BASIN     373     USA      NaN   NaN
# 2  TEXAS & LOUISIANA GULF COAST BASIN      65     USA      NaN   NaN
# 3  TEXAS & LOUISIANA GULF COAST BASIN     NaN     USA      NaN   NaN
# 4                                 NaN     NaN     USA      NaN   NaN
#
#    Surface Latitude (WGS84) Abstract  Surface Longitude (WGS84) Block  \
# 0                     29.08      175                     -96.98   NaN
# 1                     29.76      551                     -94.26   NaN
# 2                     28.90       60                     -95.60   NaN
# 3                     28.96       45                     -95.98   NaN
# 4                       NaN      NaN                        NaN   NaN
#
#    OCS Area PGC Area     Operator (Reported)       Survey  Entity ID  \
# 0       NaN    P-330    MAGNUM PRODUCING, LP     HINES, D  130836314
# 1       NaN    P-330    MAGNUM PRODUCING, LP  EL&RR RR CO  130833332
# 2       NaN    P-330    MAGNUM PRODUCING, LP   DILLARD, N  130819038
# 3       NaN    P-330    MAGNUM PRODUCING, LP      HALL, E  130785484
# 4       NaN      NaN  MAGNUM PRODUCING, L.P.          NaN  130769684
#
#    Last 12 Oil  Last 12 Gas  Last 12 Water  Other No. Cleaned County  \
# 0          NaN          NaN            NaN          0       VICTORIA
# 1      10822.0          NaN            0.0          0      JEFFERSON
# 2          NaN          NaN            NaN          0       BRAZORIA
# 3        857.0      19409.0          171.0          0      MATAGORDA
# 4        119.0          NaN            0.0     801958          (N/A)
#
#    Latest BOE Magnum Drilled (Y/N)   FIPS
# 0         NaN                    Y  48469
# 1         NaN                    Y  48245
# 2         NaN                    Y  48039
# 3         NaN                    Y  48321
# 4         NaN                    N    NaN

# %%
#finding rows with no lease name
prod[prod["Well/Lease Name"].isna()]
# Out:
#         API/UWI           Operator Alias (Legacy) Well/Lease Name Well Number  \
# 56   4224130695              MAGNUM PRODUCING, LP             NaN          1W
# 73   4248101745              MAGNUM PRODUCING, LP             NaN           3
# 74   4240932532              MAGNUM PRODUCING, LP             NaN           1
# 75   4240901423              MAGNUM PRODUCING, LP             NaN          2D
# 76            0              MAGNUM PRODUCING, LP             NaN          3A
# 77   4240930559              MAGNUM PRODUCING, LP             NaN          1M
# 121  4229730256              MAGNUM PRODUCING, LP             NaN           1
# 126  4203931498  MAGNUM PRODUCING & OPERATING CO.             NaN           2
#
#          County/Parish     Reservoir Production Type Producing Status  \
# 56         JASPER (TX)    YEGUA 7300             SWD        CANCELLED
# 73        WHARTON (TX)  MIOCENE 4300             SWD           PERMIT
# 74   SAN PATRICIO (TX)          4000             SWD           PERMIT
# 75   SAN PATRICIO (TX)          3900             SWD           PERMIT
# 76        WHARTON (TX)  MIOCENE 4300             SWD        CANCELLED
# 77   SAN PATRICIO (TX)          4000             SWD        CANCELLED
# 121      LIVE OAK (TX)        WILCOX             SWD        CANCELLED
# 126      BRAZORIA (TX)     FRIO F-28             SWD        CANCELLED
#
#     Drill Type  Measured Depth (TD)   Spud Date First Prod Date  \
# 56           D              11357.0  2003-03-15             NaN
# 73           V               7777.0  1936-03-23             NaN
# 74           V               7423.0  1998-01-13             NaN
# 75           V               4015.0  1951-01-01             NaN
# 76           V               4800.0         NaN             NaN
# 77           V               8565.0  1991-04-09             NaN
# 121          V              11600.0         NaN             NaN
# 126          V              14005.0         NaN             NaN
#
#     Last Prod Date  Months Produced  Cum Gas  Daily Gas  Cum Oil  Daily Oil  \
# 56             NaN              NaN      NaN        NaN      NaN        NaN
# 73             NaN              NaN      NaN        NaN      NaN        NaN
# 74             NaN              NaN      NaN        NaN      NaN        NaN
# 75             NaN              NaN      NaN        NaN      NaN        NaN
# 76             NaN              NaN      NaN        NaN      NaN        NaN
# 77             NaN              NaN      NaN        NaN      NaN        NaN
# 121            NaN              NaN      NaN        NaN      NaN        NaN
# 126            NaN              NaN      NaN        NaN      NaN        NaN
#
#      Latest Oil  Latest Gas  Cum Water  Cum BOE      DI Subplay  \
# 56          NaN         NaN        NaN      NaN             NaN
# 73          NaN         NaN        NaN      NaN             NaN
# 74          NaN         NaN        NaN      NaN             NaN
# 75          NaN         NaN        NaN      NaN             NaN
# 76          NaN         NaN        NaN      NaN             NaN
# 77          NaN         NaN        NaN      NaN             NaN
# 121         NaN         NaN        NaN      NaN  EAGLE FORD DRY
# 126         NaN         NaN        NaN      NaN             NaN
#
#      First Month Oil  First Month Gas  First 6 Oil            DI Basin  \
# 56               NaN              NaN          NaN  GULF COAST CENTRAL
# 73               NaN              NaN          NaN  GULF COAST CENTRAL
# 74               NaN              NaN          NaN     GULF COAST WEST
# 75               NaN              NaN          NaN     GULF COAST WEST
# 76               NaN              NaN          NaN                 NaN
# 77               NaN              NaN          NaN     GULF COAST WEST
# 121              NaN              NaN          NaN     GULF COAST WEST
# 126              NaN              NaN          NaN  GULF COAST CENTRAL
#
#      First 6 Gas  First 6 BOE  First 6 Water    DI Play  Prac IP Oil Daily  \
# 56           NaN          NaN            NaN        NaN                NaN
# 73           NaN          NaN            NaN        NaN                NaN
# 74           NaN          NaN            NaN        NaN                NaN
# 75           NaN          NaN            NaN        NaN                NaN
# 76           NaN          NaN            NaN        NaN                NaN
# 77           NaN          NaN            NaN        NaN                NaN
# 121          NaN          NaN            NaN  EAGLEFORD                NaN
# 126          NaN          NaN            NaN        NaN                NaN
#
#      Prac IP BOE  Prac IP Gas Daily  Prac IP CFGED  Latest Water  \
# 56           NaN                NaN            NaN           NaN
# 73           NaN                NaN            NaN           NaN
# 74           NaN                NaN            NaN           NaN
# 75           NaN                NaN            NaN           NaN
# 76           NaN                NaN            NaN           NaN
# 77           NaN                NaN            NaN           NaN
# 121          NaN                NaN            NaN           NaN
# 126          NaN                NaN            NaN           NaN
#
#      Prior 12 Oil  Prior 12 Gas Last Test Date  Prior 12 Water  \
# 56            NaN           NaN            NaN             NaN
# 73            NaN           NaN            NaN             NaN
# 74            NaN           NaN            NaN             NaN
# 75            NaN           NaN            NaN             NaN
# 76            NaN           NaN            NaN             NaN
# 77            NaN           NaN            NaN             NaN
# 121           NaN           NaN            NaN             NaN
# 126           NaN           NaN            NaN             NaN
#
#      Last Flow Pressure  Last WHSIP  2nd Month GOR  Latest GOR  Cum GOR  \
# 56                  NaN         NaN            NaN         NaN      NaN
# 73                  NaN         NaN            NaN         NaN      NaN
# 74                  NaN         NaN            NaN         NaN      NaN
# 75                  NaN         NaN            NaN         NaN      NaN
# 76                  NaN         NaN            NaN         NaN      NaN
# 77                  NaN         NaN            NaN         NaN      NaN
# 121                 NaN         NaN            NaN         NaN      NaN
# 126                 NaN         NaN            NaN         NaN      NaN
#
#      Last 12 Yield  2nd Month Yield  Latest Yield  Peak Gas  \
# 56             NaN              NaN           NaN       NaN
# 73             NaN              NaN           NaN       NaN
# 74             NaN              NaN           NaN       NaN
# 75             NaN              NaN           NaN       NaN
# 76             NaN              NaN           NaN       NaN
# 77             NaN              NaN           NaN       NaN
# 121            NaN              NaN           NaN       NaN
# 126            NaN              NaN           NaN       NaN
#
#      Peak Gas Month No.  Peak Oil  Peak Oil Month No.  Peak BOE  \
# 56                  NaN       NaN                 NaN       NaN
# 73                  NaN       NaN                 NaN       NaN
# 74                  NaN       NaN                 NaN       NaN
# 75                  NaN       NaN                 NaN       NaN
# 76                  NaN       NaN                 NaN       NaN
# 77                  NaN       NaN                 NaN       NaN
# 121                 NaN       NaN                 NaN       NaN
# 126                 NaN       NaN                 NaN       NaN
#
#      Peak BOE Month No.  Peak MMCFGE  Peak MMCFGE Month No.  \
# 56                  NaN          NaN                    NaN
# 73                  NaN          NaN                    NaN
# 74                  NaN          NaN                    NaN
# 75                  NaN          NaN                    NaN
# 76                  NaN          NaN                    NaN
# 77                  NaN          NaN                    NaN
# 121                 NaN          NaN                    NaN
# 126                 NaN          NaN                    NaN
#
#      Upper Perforation  Lower Perforation  Gas Gravity  Oil Gravity  \
# 56              7135.0             7833.0          NaN          NaN
# 73              3700.0             4800.0          NaN          NaN
# 74              2980.0             5820.0          NaN          NaN
# 75              2850.0             4000.0          NaN          NaN
# 76              3700.0             4800.0          NaN          NaN
# 77              2980.0             5820.0          NaN          NaN
# 121             3950.0             4900.0          NaN          NaN
# 126             4175.0             4300.0          NaN          NaN
#
#     Completion Date  Well Count  Max Active Wells Gas Gatherer Oil Gatherer  \
# 56              NaN           1               NaN          NaN          NaN
# 73       1968-04-01           1               NaN          NaN          NaN
# 74       1998-02-05           1               NaN          NaN          NaN
# 75       1987-07-06           1               NaN          NaN          NaN
# 76              NaN           1               NaN          NaN          NaN
# 77              NaN           1               NaN          NaN          NaN
# 121             NaN           1               NaN          NaN          NaN
# 126             NaN           1               NaN          NaN          NaN
#
#     Lease Number  Gross Perforated Interval  True Vertical Depth  \
# 56     000111278                      698.0                  NaN
# 73     000105153                     1100.0                  NaN
# 74     000104133                     2840.0                  NaN
# 75     000104815                     1150.0                  0.0
# 76     000105422                     1100.0                  NaN
# 77     000104134                     2840.0                  NaN
# 121    000096408                      950.0                  NaN
# 126    000088732                      125.0                  NaN
#
#             Field State District              AAPG Geologic Province Section  \
# 56           BUNA    TX       03  TEXAS & LOUISIANA GULF COAST BASIN      65
# 73         LOUISE    TX       03  TEXAS & LOUISIANA GULF COAST BASIN      23
# 74           TAFT    TX       04  TEXAS & LOUISIANA GULF COAST BASIN     NaN
# 75     TAFT, WEST    TX       04  TEXAS & LOUISIANA GULF COAST BASIN     NaN
# 76         LOUISE    TX       03  TEXAS & LOUISIANA GULF COAST BASIN     NaN
# 77           TAFT    TX       04  TEXAS & LOUISIANA GULF COAST BASIN     NaN
# 121      MCKINNEY    TX       02  TEXAS & LOUISIANA GULF COAST BASIN     NaN
# 126  FOUR CORNERS    TX       03  TEXAS & LOUISIANA GULF COAST BASIN      65
#
#     Country Township Range  Surface Latitude (WGS84) Abstract  \
# 56      USA      NaN   NaN                     30.43      510
# 73      USA      NaN   NaN                     29.06      287
# 74      USA      NaN   NaN                     28.00      129
# 75      USA      NaN   NaN                     28.02      227
# 76      USA      NaN   NaN                       NaN      NaN
# 77      USA      NaN   NaN                     28.00      129
# 121     USA      NaN   NaN                     28.39      171
# 126     USA      NaN   NaN                     29.00       26
#
#      Surface Longitude (WGS84) Block  OCS Area PGC Area  \
# 56                      -94.02   NaN       NaN    P-330
# 73                      -96.39   NaN       NaN    P-330
# 74                      -97.42     7       NaN    P-330
# 75                      -97.39   NaN       NaN    P-330
# 76                         NaN   NaN       NaN    P-330
# 77                      -97.42   NaN       NaN    P-330
# 121                     -98.02   NaN       NaN    P-330
# 126                     -95.69   NaN       NaN    P-330
#
#                   Operator (Reported)       Survey  Entity ID  Last 12 Oil  \
# 56               MAGNUM PRODUCING, LP   T&NO RR CO  128925762          NaN
# 73               MAGNUM PRODUCING, LP          M&C  128275019          NaN
# 74               MAGNUM PRODUCING, LP    GARCIA, J  128274915          NaN
# 75               MAGNUM PRODUCING, LP      ROSS, R  128274357          NaN
# 76               MAGNUM PRODUCING, LP          NaN  128273620          NaN
# 77               MAGNUM PRODUCING, LP    GARCIA, J  128273299          NaN
# 121              MAGNUM PRODUCING, LP       ELY, J  124485316          NaN
# 126  MAGNUM PRODUCING & OPERATING CO.  AUSTIN, S F  124478838          NaN
#
#      Last 12 Gas  Last 12 Water  Other No. Cleaned County  Latest BOE  \
# 56           NaN            NaN          0         JASPER         NaN
# 73           NaN            NaN          0        WHARTON         NaN
# 74           NaN            NaN          0   SAN PATRICIO         NaN
# 75           NaN            NaN          0   SAN PATRICIO         NaN
# 76           NaN            NaN          0        WHARTON         NaN
# 77           NaN            NaN          0   SAN PATRICIO         NaN
# 121          NaN            NaN          0       LIVE OAK         NaN
# 126          NaN            NaN          0       BRAZORIA         NaN
#
#     Magnum Drilled (Y/N)   FIPS
# 56                     N  48241
# 73                     N  48481
# 74                     N  48409
# 75                     N  48409
# 76                     N  48481
# 77                     N  48409
# 121                    N  48297
# 126                    N  48039

# %%
#dropping rows in table with no well name since they were all SWD wells that were permits or cancelled
prod.drop(index = prod[prod["Well/Lease Name"].isna()].index, inplace = True)

# %% [markdown]
# ## Exporting Prepared Production Table to File

# %%
prod.to_excel("Data for Tableau - Do not Edit Files in Here/Prepared Production Table.xlsx", index = False)

# %% [markdown]
# <hr>
#
# # Stopping Point - Code below is Irrelevant as of 6/25/21
#
# <hr>

# %% [markdown]
# ## Merging Well List with Sell Information

# %%
import os

# %%
sellInfoDF = pd.read_excel('VOID Well - Sell Intention - Table.xlsx')
sellInfoDF.drop(index = sellInfoDF[sellInfoDF["Well/Lease Name"].isna()].index, inplace = True)

# %%
#source code to add sheet to existing workbook is found here: 
#https://stackoverflow.com/questions/42370977/how-to-save-a-new-sheet-in-an-existing-excel-file-using-pandas

from openpyxl import load_workbook

#path of where excel file is to add sheet to
path = os.path.abspath('Data for Tableau - Do not Edit Files in Here/Prepared Production Table.xlsx')

book = load_workbook(path)
writer = pd.ExcelWriter(path, engine = 'openpyxl')
writer.book = book


sellInfoDF.to_excel(writer, sheet_name = 'Well Sale List', index = False)
writer.save()
writer.close()

# %% [markdown]
# # Merging Coworker's (Anish's) Version

# %%
#Storing sheet names needed to unify tables
sheets = pd.ExcelFile("Magnum TX RRC Sell Intention.xlsx").sheet_names[:3]
sheets
# Out:
# ['Magnum Engineering', 'Magnum Operating, LLC', 'Magnum Producing, LP']

# %%
dfList = []


for sheet in sheets:
    temp = pd.read_excel('Magnum TX RRC Sell Intention.xlsx', header = 1, sheet_name=sheet)
    dfList.append(temp)
    
anishDF = pd.concat(dfList, sort=False)

# %%
sellInfoDF.head(2)
sellInfoDF.info()
anishDF.head(2)
anishDF.info()
# Out:
#       API/UWI              Well/Lease Name Well Number    County/Parish  \
# 0  1709901012  11000 RA SUA;HENRY MELANCON         001  ST. MARTIN (LA)
# 1  4201530644                 A. SCHROEDER           1      AUSTIN (TX)
#
#   Sale Intention  Well Logs  Wellbore Diagram  Equipment List  \
# 0           SELL        NaN               NaN             NaN
# 1            NaN        NaN               NaN             NaN
#
#    Geological Presentation  LOS  Purchase Statements  Lease Exhibit  \
# 0                      NaN  NaN                  NaN            NaN
# 1                      NaN  NaN                  NaN            NaN
#
#   Executed P4 (Change of Operator) Executed Bill of Sale
# 0                                N                     N
# 1                                N                     N
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 445 entries, 0 to 444
# Data columns (total 14 columns):
# API/UWI                             445 non-null int64
# Well/Lease Name                     445 non-null object
# Well Number                         394 non-null object
# County/Parish                       445 non-null object
# Sale Intention                      49 non-null object
# Well Logs                           0 non-null float64
# Wellbore Diagram                    0 non-null float64
# Equipment List                      0 non-null float64
# Geological Presentation             0 non-null float64
# LOS                                 0 non-null float64
# Purchase Statements                 0 non-null float64
# Lease Exhibit                       0 non-null float64
# Executed P4 (Change of Operator)    445 non-null object
# Executed Bill of Sale               445 non-null object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 52.1+ KB
#           API  Lease No.      Lease Name Well No.               Operator Name  \
# 0  4202532776     161800  ALGEA GAS UNIT        3  MAGNUM ENGINEERING COMPANY
# 1  4202532776     212589  ALGEA GAS UNIT        3  MAGNUM ENGINEERING COMPANY
#
#   County Status  Sale Intention                  Field Name On Schedule  \
# 0    BEE    NaN             NaN  ORANGEDALE (LULING, LOWER)           N
# 1    BEE    NaN             NaN   THEIS, SOUTH(SLICK FIRST)           Y
#
#   Folder on Well File Well Logs Well Reports Wellbore Diagram  Equipment List  \
# 0                 NaN       NaN          NaN              NaN             NaN
# 1                 NaN       NaN          NaN              NaN             NaN
#
#   Geological Presentation  LOS  Purchase Statements Lease Exhibit  \
# 0                     NaN  NaN                  NaN           NaN
# 1                     NaN  NaN                  NaN           NaN
#
#    Executed P4 (Change of Operator) Executed Bill of Sale
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 789 entries, 0 to 606
# Data columns (total 21 columns):
# API                                 789 non-null int64
# Lease No.                           789 non-null int64
# Lease Name                          789 non-null object
# Well No.                            789 non-null object
# Operator Name                       789 non-null object
# County                              789 non-null object
# Status                              80 non-null object
# Sale Intention                      0 non-null float64
# Field Name                          789 non-null object
# On Schedule                         789 non-null object
# Folder on Well File                 44 non-null object
# Well Logs                           1 non-null object
# Well Reports                        1 non-null object
# Wellbore Diagram                    2 non-null object
# Equipment List                      0 non-null float64
# Geological Presentation             1 non-null object
# LOS                                 0 non-null float64
# Purchase Statements                 0 non-null float64
# Lease Exhibit                       7 non-null object
# Executed P4 (Change of Operator)    0 non-null float64
# Executed Bill of Sale               37 non-null object
# dtypes: float64(5), int64(2), object(14)
# memory usage: 135.6+ KB

# %%
leftTable = sellInfoDF[["API/UWI", "Well/Lease Name", "Sale Intention"]]
rightTable = anishDF.drop(columns=["Sale Intention", "Lease Name", "On Schedule"])
rightTable.rename(columns = {"API": "API/UWI"}, inplace = True)

# %%
mergedDF = pd.merge(leftTable, rightTable, how = "left", on = "API/UWI")
mergedDF
# Out:
#         API/UWI              Well/Lease Name Sale Intention  Lease No.  \
# 0    1709901012  11000 RA SUA;HENRY MELANCON           SELL        NaN
# 1    4201530644                 A. SCHROEDER            NaN    25654.0
# 2    4201530644                 A. SCHROEDER            NaN    27151.0
# 3    4201530644                 A. SCHROEDER            NaN   172789.0
# 4    4250536460                ALEXANDER "A"           SELL   255119.0
# 5    4250536379                ALEXANDER "A"           SELL   248176.0
# 6    4250536309                ALEXANDER "A"           SELL   244496.0
# 7    4250536309                ALEXANDER "A"           SELL   247748.0
# 8    4247940805              ALEXANDER RANCH            NaN   256324.0
# 9    4202532833                        ALGEA            NaN   165204.0
# 10   4202532833                        ALGEA            NaN   168121.0
# 11   4202532776               ALGEA GAS UNIT            NaN   161800.0
# 12   4202532776               ALGEA GAS UNIT            NaN   212589.0
# 13   4232132401                     ANDERSON            NaN    27736.0
# 14   4232132361                     ANDERSON            NaN    26834.0
# 15   4232132361                     ANDERSON            NaN   275419.0
# 16   4232132383            ANDERSON-THOMPSON            NaN    27142.0
# 17   4208932482     ANDERSON, MARK N., ET UX            NaN   221747.0
# 18   4212330992              ANGERSTEIN, H O           SELL   207897.0
# 19   4212331885              APACHE GAS UNIT            NaN   180694.0
# 20   4212331885              APACHE GAS UNIT            NaN   203190.0
# 21   4228532829                APPLING FARMS            NaN   181968.0
# 22   4223930213           APPLING, F. E. -B-            NaN        NaN
# 23   4207131688       B.B. ROGERS GAS UNIT 1            NaN    22499.0
# 24   4207131688       B.B. ROGERS GAS UNIT 1            NaN    22499.0
# 25   4207131688       B.B. ROGERS GAS UNIT 1            NaN    22499.0
# 26   4207131688       B.B. ROGERS GAS UNIT 1            NaN   177245.0
# 27   4207131688       B.B. ROGERS GAS UNIT 1            NaN   201104.0
# 28   4229733915                  BAKER, EARL            NaN   132992.0
# 29   4229702494                  BAKER, EARL            NaN   127436.0
# ..          ...                          ...            ...        ...
# 574  4208930440     WEGENHOFT, JOHN AND FORD            NaN        NaN
# 575  4224731567                  WEST COYOTE            NaN   109848.0
# 576   302711440                WHITEHEAD "B"            NaN        NaN
# 577   302711458                WHITEHEAD "B"            NaN        NaN
# 578   302701139                WHITEHEAD "B"            NaN        NaN
# 579  4223933353                     WILLIAMS            NaN   223863.0
# 580  4223933353                     WILLIAMS            NaN   224928.0
# 581  4229102452              WILLIAMS, J. D.            NaN     1177.0
# 582  4229102467              WILLIAMS, J. D.            NaN     1177.0
# 583  4229102450              WILLIAMS, J. D.            NaN     1177.0
# 584  4229102457              WILLIAMS, J. D.            NaN     1177.0
# 585  4229102457              WILLIAMS, J. D.            NaN   149260.0
# 586  4229132222          WILLIAMS, J. D. -C-            NaN    22711.0
# 587  4229132224          WILLIAMS, J. D. -C-            NaN   155453.0
# 588  4229132097          WILLIAMS, J. D. 'B'            NaN   189093.0
# 589  4229132257          WILLIAMS, J. D. "D"            NaN    23140.0
# 590  4229132096           WILLIAMS, J.D. -B-            NaN    20714.0
# 591  4216730592             WILSON, B. LOBIT            NaN        NaN
# 592  4201530132         WINTERBOTHAM, JOHN M            NaN    23718.0
# 593  4208930044            WINTERMAN, ADA M.            NaN   194927.0
# 594  4208930093                   WINTERMANN            NaN    50040.0
# 595  4203931452        WITTJEN, GADDIS ET AL            NaN        NaN
# 596  4208932001      WOLF-GLASSCOCK GAS UNIT            NaN        NaN
# 597  4208931333              YOUENS GAS UNIT            NaN        NaN
# 598  4208930154        YOUENS, W.T. GAS UNIT            NaN        NaN
# 599  4208930256           ZAHRADNICK, ALFRED            NaN    91859.0
# 600  4231732011                         ZANT            NaN    62249.0
# 601  4211531212                     ZANT "A"            NaN    62213.0
# 602  4231732059                     ZANT "B"            NaN    62432.0
# 603  4212331934                     ZENGERLE            NaN   200152.0
#
#     Well No.               Operator Name     County  \
# 0        NaN                         NaN        NaN
# 1          1        MAGNUM PRODUCING, LP     AUSTIN
# 2          1        MAGNUM PRODUCING, LP     AUSTIN
# 3          1        MAGNUM PRODUCING, LP     AUSTIN
# 4          3        MAGNUM PRODUCING, LP     ZAPATA
# 5          2        MAGNUM PRODUCING, LP     ZAPATA
# 6          1        MAGNUM PRODUCING, LP     ZAPATA
# 7          1        MAGNUM PRODUCING, LP     ZAPATA
# 8          1        MAGNUM PRODUCING, LP       WEBB
# 9          1  MAGNUM ENGINEERING COMPANY        BEE
# 10         1  MAGNUM ENGINEERING COMPANY        BEE
# 11         3  MAGNUM ENGINEERING COMPANY        BEE
# 12         3  MAGNUM ENGINEERING COMPANY        BEE
# 13         3        MAGNUM PRODUCING, LP  MATAGORDA
# 14        1C        MAGNUM PRODUCING, LP  MATAGORDA
# 15        1T        MAGNUM PRODUCING, LP  MATAGORDA
# 16         2        MAGNUM PRODUCING, LP  MATAGORDA
# 17         1        MAGNUM PRODUCING, LP   COLORADO
# 18         1        MAGNUM PRODUCING, LP    DE WITT
# 19         1        MAGNUM PRODUCING, LP    DE WITT
# 20         1        MAGNUM PRODUCING, LP    DE WITT
# 21         1        MAGNUM PRODUCING, LP     LAVACA
# 22       NaN                         NaN        NaN
# 23         2        MAGNUM PRODUCING, LP   CHAMBERS
# 24        2T        MAGNUM PRODUCING, LP   CHAMBERS
# 25        2U        MAGNUM PRODUCING, LP   CHAMBERS
# 26       2-C        MAGNUM PRODUCING, LP   CHAMBERS
# 27        2C        MAGNUM PRODUCING, LP   CHAMBERS
# 28        9A        MAGNUM PRODUCING, LP   LIVE OAK
# 29        1A        MAGNUM PRODUCING, LP   LIVE OAK
# ..       ...                         ...        ...
# 574      NaN                         NaN        NaN
# 575        1        MAGNUM PRODUCING, LP   JIM HOGG
# 576      NaN                         NaN        NaN
# 577      NaN                         NaN        NaN
# 578      NaN                         NaN        NaN
# 579        1        MAGNUM PRODUCING, LP    JACKSON
# 580        1        MAGNUM PRODUCING, LP    JACKSON
# 581        7  MAGNUM ENGINEERING COMPANY    LIBERTY
# 582       22  MAGNUM ENGINEERING COMPANY    LIBERTY
# 583        5  MAGNUM ENGINEERING COMPANY    LIBERTY
# 584       12  MAGNUM ENGINEERING COMPANY    LIBERTY
# 585       12  MAGNUM ENGINEERING COMPANY    LIBERTY
# 586       26  MAGNUM ENGINEERING COMPANY    LIBERTY
# 587       28  MAGNUM ENGINEERING COMPANY    LIBERTY
# 588       23  MAGNUM ENGINEERING COMPANY    LIBERTY
# 589       29  MAGNUM ENGINEERING COMPANY    LIBERTY
# 590       25  MAGNUM ENGINEERING COMPANY    LIBERTY
# 591      NaN                         NaN        NaN
# 592        1        MAGNUM PRODUCING, LP     AUSTIN
# 593        1        MAGNUM PRODUCING, LP   COLORADO
# 594        2        MAGNUM PRODUCING, LP   COLORADO
# 595      NaN                         NaN        NaN
# 596      NaN                         NaN        NaN
# 597      NaN                         NaN        NaN
# 598      NaN                         NaN        NaN
# 599        1        MAGNUM PRODUCING, LP   COLORADO
# 600        1  MAGNUM ENGINEERING COMPANY     MARTIN
# 601        1  MAGNUM ENGINEERING COMPANY     DAWSON
# 602        1  MAGNUM ENGINEERING COMPANY     MARTIN
# 603        1        MAGNUM PRODUCING, LP    DE WITT
#
#                                                 Status  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 574                                                NaN
# 575                                                NaN
# 576                                                NaN
# 577                                                NaN
# 578                                                NaN
# 579                                                NaN
# 580                                                NaN
# 581                           Shut in - Injection Well
# 582                                     Injection Well
# 583                           Dry Hole - P&A - 10/2011
# 584                                      P&A - 12/2009
# 585                                      P&A - 12/2009
# 586                                             Active
# 587  No prod info on RRC since 12/1997. Temp Abandoned
# 588  No prod info on RRC since 01/2004. Temp Abandoned
# 589                     Well shut in (Lease Producing)
# 590                    Well Inactive (Lease Producing)
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
# 594                                                NaN
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
# 600                                                NaN
# 601                                                NaN
# 602                                                NaN
# 603                                                NaN
#
#                            Field Name                   Folder on Well File  \
# 0                                 NaN                                   NaN
# 1         BLEIBLERVILLE (WILCOX 9200)                                   NaN
# 2         BLEIBLERVILLE (WILCOX 9000)                                   NaN
# 3         BLEIBLERVILLE (WILCOX 9540)                                   NaN
# 4                  EXSUN (LOBO CONS.)                                   NaN
# 5                  EXSUN (LOBO CONS.)                                   NaN
# 6                  EXSUN (LOBO CONS.)                                   NaN
# 7                      BIG MAC (6470)                                   NaN
# 8                    VALLEY (NAVARRO)                                   NaN
# 9              MALCOMB (3608 HOCKLEY)                                   NaN
# 10                     MALCOMB (1270)                                   NaN
# 11         ORANGEDALE (LULING, LOWER)                                   NaN
# 12          THEIS, SOUTH(SLICK FIRST)                                   NaN
# 13              LUCKY, EAST (HUEBNER)                                   NaN
# 14                      LUCKY ( GOLA)                                   NaN
# 15             LUCKY (THOMPSON 10100)                                   NaN
# 16                            WILDCAT                                   NaN
# 17   CHESTERVILLE, NORTH (YEGUA 6000)                                   NaN
# 18   COTTONWOOD CREEK, S. (FRIO 2300)                                   NaN
# 19            WENDLING (WILCOX 12850)                                   NaN
# 20            WENDLING (WILCOX 11200)                                   NaN
# 21                      VIENNA (8450)                                   NaN
# 22                                NaN                                   NaN
# 23                WHITES BAYOU (F-16)                                   NaN
# 24                WHITES BAYOU (F-16)                                   NaN
# 25                WHITES BAYOU (F-16)                                   NaN
# 26              WHITES BAYOU (F-15-C)                                   NaN
# 27                WHITES BAYOU (F-14)                                   NaN
# 28                 BAKER (LULING SD.)                                   NaN
# 29               BAKER (WILCOX 10000)                                   NaN
# ..                                ...                                   ...
# 574                               NaN                                   NaN
# 575         COYOTE, WEST (QUEEN CITY)                                   NaN
# 576                               NaN                                   NaN
# 577                               NaN                                   NaN
# 578                               NaN                                   NaN
# 579    MORALES, NORTH (MIDDLE WILCOX)                                   NaN
# 580                MORALES, N. (9250)                                   NaN
# 581         DAYTON, NORTH (5000 SAND)                                    No
# 582         DAYTON, NORTH (5000 SAND)                                    No
# 583         DAYTON, NORTH (5000 SAND)  No (P&A Ltr in N Dayton Field folder
# 584         DAYTON, NORTH (5000 SAND)                                    No
# 585         DAYTON, NORTH (5000 SAND)                                    No
# 586         DAYTON, NORTH (5000 SAND)                                    No
# 587      DAYTON, NORTH (MIOCENE 2400)                                    No
# 588         DAYTON, NORTH (5000 SAND)                                    No
# 589         DAYTON, NORTH (5000 SAND)                                    No
# 590         DAYTON, NORTH (5000 SAND)                                    No
# 591                               NaN                                   NaN
# 592      NELSONVILLE ( WILCOX  9,200)                                   NaN
# 593              RAMSEY (8600 WILCOX)                                   NaN
# 594          RAMSEY, E. (WILCOX 9350)                                   NaN
# 595                               NaN                                   NaN
# 596                               NaN                                   NaN
# 597                               NaN                                   NaN
# 598                               NaN                                   NaN
# 599         RAMSEY, E. (WILCOX 10300)                                   NaN
# 600               ACKERLY (DEAN SAND)                                   NaN
# 601               ACKERLY (DEAN SAND)                                   NaN
# 602               ACKERLY (DEAN SAND)                                   NaN
# 603              BRANDT (WILCOX DEEP)                                   NaN
#
#     Well Logs Well Reports Wellbore Diagram  Equipment List  \
# 0         NaN          NaN              NaN             NaN
# 1         NaN          NaN              NaN             NaN
# 2         NaN          NaN              NaN             NaN
# 3         NaN          NaN              NaN             NaN
# 4         NaN          NaN              NaN             NaN
# 5         NaN          NaN              NaN             NaN
# 6         NaN          NaN              NaN             NaN
# 7         NaN          NaN              NaN             NaN
# 8         NaN          NaN              NaN             NaN
# 9         NaN          NaN              NaN             NaN
# 10        NaN          NaN              NaN             NaN
# 11        NaN          NaN              NaN             NaN
# 12        NaN          NaN              NaN             NaN
# 13        NaN          NaN              NaN             NaN
# 14        NaN          NaN              NaN             NaN
# 15        NaN          NaN              NaN             NaN
# 16        NaN          NaN              NaN             NaN
# 17        NaN          NaN              NaN             NaN
# 18        NaN          NaN              NaN             NaN
# 19        NaN          NaN              NaN             NaN
# 20        NaN          NaN              NaN             NaN
# 21        NaN          NaN              NaN             NaN
# 22        NaN          NaN              NaN             NaN
# 23        NaN          NaN              NaN             NaN
# 24        NaN          NaN              NaN             NaN
# 25        NaN          NaN              NaN             NaN
# 26        NaN          NaN              NaN             NaN
# 27        NaN          NaN              NaN             NaN
# 28        NaN          NaN              NaN             NaN
# 29        NaN          NaN              NaN             NaN
# ..        ...          ...              ...             ...
# 574       NaN          NaN              NaN             NaN
# 575       NaN          NaN              NaN             NaN
# 576       NaN          NaN              NaN             NaN
# 577       NaN          NaN              NaN             NaN
# 578       NaN          NaN              NaN             NaN
# 579       NaN          NaN              NaN             NaN
# 580       NaN          NaN              NaN             NaN
# 581       NaN          NaN              NaN             NaN
# 582       NaN          NaN              NaN             NaN
# 583       NaN          NaN              NaN             NaN
# 584       NaN          NaN              NaN             NaN
# 585       NaN          NaN              NaN             NaN
# 586       NaN          NaN              NaN             NaN
# 587       NaN          NaN              NaN             NaN
# 588       NaN          NaN              NaN             NaN
# 589       NaN          NaN              NaN             NaN
# 590       NaN          NaN              NaN             NaN
# 591       NaN          NaN              NaN             NaN
# 592       NaN          NaN              NaN             NaN
# 593       NaN          NaN              NaN             NaN
# 594       NaN          NaN              NaN             NaN
# 595       NaN          NaN              NaN             NaN
# 596       NaN          NaN              NaN             NaN
# 597       NaN          NaN              NaN             NaN
# 598       NaN          NaN              NaN             NaN
# 599       NaN          NaN              NaN             NaN
# 600       NaN          NaN              NaN             NaN
# 601       NaN          NaN              NaN             NaN
# 602       NaN          NaN              NaN             NaN
# 603       NaN          NaN              NaN             NaN
#
#     Geological Presentation  LOS  Purchase Statements Lease Exhibit  \
# 0                       NaN  NaN                  NaN           NaN
# 1                       NaN  NaN                  NaN           NaN
# 2                       NaN  NaN                  NaN           NaN
# 3                       NaN  NaN                  NaN           NaN
# 4                       NaN  NaN                  NaN           NaN
# 5                       NaN  NaN                  NaN           NaN
# 6                       NaN  NaN                  NaN           NaN
# 7                       NaN  NaN                  NaN           NaN
# 8                       NaN  NaN                  NaN           NaN
# 9                       NaN  NaN                  NaN           NaN
# 10                      NaN  NaN                  NaN           NaN
# 11                      NaN  NaN                  NaN           NaN
# 12                      NaN  NaN                  NaN           NaN
# 13                      NaN  NaN                  NaN           NaN
# 14                      NaN  NaN                  NaN           NaN
# 15                      NaN  NaN                  NaN           NaN
# 16                      NaN  NaN                  NaN           NaN
# 17                      NaN  NaN                  NaN           NaN
# 18                      NaN  NaN                  NaN           NaN
# 19                      NaN  NaN                  NaN           NaN
# 20                      NaN  NaN                  NaN           NaN
# 21                      NaN  NaN                  NaN           NaN
# 22                      NaN  NaN                  NaN           NaN
# 23                      NaN  NaN                  NaN           NaN
# 24                      NaN  NaN                  NaN           NaN
# 25                      NaN  NaN                  NaN           NaN
# 26                      NaN  NaN                  NaN           NaN
# 27                      NaN  NaN                  NaN           NaN
# 28                      NaN  NaN                  NaN           NaN
# 29                      NaN  NaN                  NaN           NaN
# ..                      ...  ...                  ...           ...
# 574                     NaN  NaN                  NaN           NaN
# 575                     NaN  NaN                  NaN           NaN
# 576                     NaN  NaN                  NaN           NaN
# 577                     NaN  NaN                  NaN           NaN
# 578                     NaN  NaN                  NaN           NaN
# 579                     NaN  NaN                  NaN           NaN
# 580                     NaN  NaN                  NaN           NaN
# 581                     NaN  NaN                  NaN           NaN
# 582                     NaN  NaN                  NaN           NaN
# 583                     NaN  NaN                  NaN           NaN
# 584                     NaN  NaN                  NaN           NaN
# 585                     NaN  NaN                  NaN           NaN
# 586                     NaN  NaN                  NaN           NaN
# 587                     NaN  NaN                  NaN           NaN
# 588                     NaN  NaN                  NaN           NaN
# 589                     NaN  NaN                  NaN           NaN
# 590                     NaN  NaN                  NaN           NaN
# 591                     NaN  NaN                  NaN           NaN
# 592                     NaN  NaN                  NaN           NaN
# 593                     NaN  NaN                  NaN           NaN
# 594                     NaN  NaN                  NaN           NaN
# 595                     NaN  NaN                  NaN           NaN
# 596                     NaN  NaN                  NaN           NaN
# 597                     NaN  NaN                  NaN           NaN
# 598                     NaN  NaN                  NaN           NaN
# 599                     NaN  NaN                  NaN           NaN
# 600                     NaN  NaN                  NaN           NaN
# 601                     NaN  NaN                  NaN           NaN
# 602                     NaN  NaN                  NaN           NaN
# 603                     NaN  NaN                  NaN           NaN
#
#      Executed P4 (Change of Operator) Executed Bill of Sale
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
# 5                                 NaN                   NaN
# 6                                 NaN                   NaN
# 7                                 NaN                   NaN
# 8                                 NaN                   NaN
# 9                                 NaN                   NaN
# 10                                NaN                   NaN
# 11                                NaN                   NaN
# 12                                NaN                   NaN
# 13                                NaN                   NaN
# 14                                NaN                   NaN
# 15                                NaN                   NaN
# 16                                NaN                   NaN
# 17                                NaN                   NaN
# 18                                NaN                   NaN
# 19                                NaN                   NaN
# 20                                NaN                   NaN
# 21                                NaN                   NaN
# 22                                NaN                   NaN
# 23                                NaN                   NaN
# 24                                NaN                   NaN
# 25                                NaN                   NaN
# 26                                NaN                   NaN
# 27                                NaN                   NaN
# 28                                NaN                   NaN
# 29                                NaN                   NaN
# ..                                ...                   ...
# 574                               NaN                   NaN
# 575                               NaN                   NaN
# 576                               NaN                   NaN
# 577                               NaN                   NaN
# 578                               NaN                   NaN
# 579                               NaN                   NaN
# 580                               NaN                   NaN
# 581                               NaN                   NaN
# 582                               NaN                   NaN
# 583                               NaN                   NaN
# 584                               NaN                   NaN
# 585                               NaN                   NaN
# 586                               NaN                   NaN
# 587                               NaN                   NaN
# 588                               NaN                   NaN
# 589                               NaN                   NaN
# 590                               NaN                   NaN
# 591                               NaN                   NaN
# 592                               NaN                   NaN
# 593                               NaN                   NaN
# 594                               NaN                   NaN
# 595                               NaN                   NaN
# 596                               NaN                   NaN
# 597                               NaN                   NaN
# 598                               NaN                   NaN
# 599                               NaN                   NaN
# 600                               NaN                   NaN
# 601                               NaN                   NaN
# 602                               NaN                   NaN
# 603                               NaN                   NaN
#
# [604 rows x 20 columns]
