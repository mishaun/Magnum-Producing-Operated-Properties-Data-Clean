# %% [markdown]
# # Project Goals
#
# * Import spreadsheet having multiple sheets holding state information of non operated wells for company
# * Merge all sheets into unified table.
#     * All sheets have similar data fields, but may vary by name, or duplicate columns holding identicical field information may have been added
#     *  This will result in a large, messy table, where multiple columns holding identical information will need to be merged
#         * For example: A data sheet may have 4 different columns holding comments from 4 separate people, we would like to merge this into one column, "Comments"

# %%
import pandas as pd
import numpy as np
import re
import pdb

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('precision', 2)

# %% [markdown]
# ## Read In Data

# %%
workbook = pd.ExcelFile('Energynet OBO Well List.xlsx')
sheetNames = workbook.sheet_names
sheetNames
# Out:
# ['Texas',
#  'New Mexico',
#  'Oklahoma',
#  'Mississippi',
#  'Louisiana',
#  'Alabama',
#  'Arkansas',
#  'North Dakota',
#  'Montana',
#  'Michigan',
#  'NEBRASKA',
#  'Kansas',
#  'COLORADO',
#  'Raccoon Bend Field',
#  'WYOMING',
#  'OHIO',
#  'Sheet1',
#  'Sheet2']

# %%
#cleaning up sheetnames not needed
sheetNames = list(filter(lambda x: "Rac" not in x, sheetNames))
sheetNames = list(filter(lambda x: "heet" not in x, sheetNames))

sheetNames
# Out:
# ['Texas',
#  'New Mexico',
#  'Oklahoma',
#  'Mississippi',
#  'Louisiana',
#  'Alabama',
#  'Arkansas',
#  'North Dakota',
#  'Montana',
#  'Michigan',
#  'NEBRASKA',
#  'Kansas',
#  'COLORADO',
#  'WYOMING',
#  'OHIO']

# %% [markdown]
# ### Adding each sheet's dataframe to list for concatenating

# %%
stateDFs = []

for name in sheetNames:
    tempDF = pd.read_excel('Energynet OBO Well List.xlsx', sheet_name=name)
    tempDF["ST"] = name.title() #adding column with respective state information
    stateDFs.append(tempDF)

# %%
stateDFs[0].head(5)
# Out:
#       COUNTY                   FILE NAME  API Number    Mishaun Notes on Well  \
# 0     DEWITT                HENSON GU #1  4212300017  Already decided to keep
# 1     DEWITT               HENSON GU #2H         NaN  Already decided to keep
# 2     DEWITT               HENSON GU #3H         NaN  Already decided to keep
# 3   COLORADO                  LUCKETT #1  4208932360                      NaN
# 4  JEFFERSON  PETKOVSEK, LOLIA. ET AL #1  4224532445                      NaN
#
#          Anish’s Comments  SHRED KEEP/STORE  Storage Downstairs  \
# 0                  Active    NaN       keep                 NaN
# 1          Well not found    NaN       keep                 NaN
# 2          Well not found    NaN       keep                 NaN
# 3  Inactive since 12/2011    NaN        NaN                 NaN
# 4                  Active    NaN        NaN                 NaN
#
#    Offsite Storage PROSPECT  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                             OPERATOR          FILE TYPE  \
# 0                  ABRAXAS (Current Operator: Atlas)               WELL
# 1                                            ABRAXAS               WELL
# 2                                            ABRAXAS               ORRI
# 3  ACOCK-ANAQUA (Current Operator: Magnum Producing)  LAND / WELL / LOG
# 4                    ALEGRE ENERGY (Current Op: S&S)               WELL
#
#    OWNER INTEREST                            REMARKS    OPEN DATE  \
# 0   MPLP      NaN                                NaN          NaN
# 1   MPLP      NaN                                NaN          NaN
# 2   MPLP      NaN                                NaN          NaN
# 3  R & R      NaN  OPERATED BY MAGNUM EFFECTIVE 7/09          NaN
# 4   MPLP      NaN                                NaN  7/1/2012 km
#
#   OPEN MEMO TO OFFICE/FILE CLOSED MEMO TO OFFICE/FILE     ST
# 0                      NaN                        NaN  Texas
# 1                      NaN                        NaN  Texas
# 2                      NaN                        NaN  Texas
# 3                      NaN                        NaN  Texas
# 4   Aspect Former Operator                        NaN  Texas

# %% [markdown]
# ## Merging all sheets together
# ### Append Each State's Table on Top of Each Other - Creates Messy Super Table

# %%
mergedDF = pd.concat(stateDFs)

mergedDF.to_excel('Test_merges/testMerge1.xlsx') #exporting messy table to excel to take a look manually

mergedDF.shape
mergedDF.info()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (1421, 69)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 0
# Data columns (total 69 columns):
# API                           3 non-null float64
# API Number                    328 non-null object
# Anish’s Comments              123 non-null object
# CLOSED MEMO TO OFFICE/FILE    11 non-null object
# COUNTY                        1342 non-null object
# Column1                       37 non-null object
# Column10                      37 non-null object
# Column11                      37 non-null object
# Column12                      37 non-null object
# Column13                      37 non-null object
# Column14                      37 non-null object
# Column15                      37 non-null object
# Column16                      37 non-null object
# Column17                      37 non-null object
# Column18                      37 non-null object
# Column2                       37 non-null object
# Column3                       37 non-null object
# Column4                       37 non-null object
# Column5                       37 non-null object
# Column6                       37 non-null object
# Column7                       37 non-null object
# Column8                       37 non-null object
# Column9                       37 non-null object
# Comments                      85 non-null object
# FILE NAME                     1404 non-null object
# FILE TYPE                     1345 non-null object
# INTEREST                      178 non-null object
# INTEREST %                    107 non-null object
# KEEP                          21 non-null object
# KEEP/STORE                    147 non-null object
# Mishaun Notes on Well         178 non-null object
# Notes on the Well             55 non-null object
# OPEN DATE                     470 non-null object
# OPEN MEMO TO OFFICE/FILE      51 non-null object
# OPENED                        29 non-null object
# OPERATOR                      1237 non-null object
# OWNER                         1330 non-null object
# Offsite Storage               11 non-null object
# Offsite Storage               0 non-null float64
# PARISH                        57 non-null object
# PROSPECT                      671 non-null object
# PROSPECT/DESCRIPT.            21 non-null object
# REMARKS                       307 non-null object
# SHRED                         16 non-null object
# ST                            1421 non-null object
# Sagar's Comments              8 non-null object
# Sagar’s Comments              85 non-null object
# Sell (Y/N)                    0 non-null float64
# Storage Downstairs            2 non-null object
# Unnamed: 15                   0 non-null float64
# Unnamed: 34                   0 non-null float64
# Unnamed: 35                   9 non-null object
# Unnamed: 36                   9 non-null object
# Unnamed: 37                   9 non-null datetime64[ns]
# Unnamed: 38                   9 non-null float64
# Unnamed: 39                   9 non-null float64
# Unnamed: 40                   9 non-null float64
# Unnamed: 41                   9 non-null float64
# Unnamed: 42                   9 non-null float64
# Unnamed: 43                   9 non-null float64
# Unnamed: 44                   9 non-null float64
# Unnamed: 45                   9 non-null float64
# Unnamed: 46                   9 non-null float64
# Unnamed: 47                   9 non-null float64
# Unnamed: 48                   9 non-null float64
# Unnamed: 49                   9 non-null float64
# Unnamed: 50                   9 non-null float64
# Unnamed: 51                   9 non-null object
# Unnamed: 52                   9 non-null object
# dtypes: datetime64[ns](1), float64(18), object(50)
# memory usage: 777.1+ KB

# %% [markdown]
# ## Cleaning and Dropping Columns

# %%
mergedDF[~mergedDF['Column1'].isna()]
# Out:
#     API API Number Anish’s Comments CLOSED MEMO TO OFFICE/FILE       COUNTY  \
# 1   NaN    3.5e+09              NaN                        NaN      ALFALFA
# 2   NaN    3.5e+09              NaN                        NaN       BEAVER
# 3   NaN    3.5e+09              NaN                        NaN       BEAVER
# 4   NaN    3.5e+09              NaN                        NaN       BEAVER
# 5   NaN        NaN              NaN                        NaN      BECKHAM
# 6   NaN        NaN              NaN                        NaN       BLAINE
# 29  NaN        NaN              NaN                        NaN        ELLIS
# 30  NaN    3.5e+09              NaN                        NaN        ELLIS
# 31  NaN    3.5e+09              NaN                        NaN        ELLIS
# 32  NaN    3.5e+09              NaN                        NaN        ELLIS
# 33  NaN    3.5e+09              NaN                        NaN        ELLIS
# 34  NaN        NaN              NaN                        NaN        ELLIS
# 35  NaN        NaN              NaN                        NaN     GARFIELD
# 36  NaN    3.5e+09              NaN                        NaN     GARFIELD
# 37  NaN    3.5e+09              NaN                        NaN     GARFIELD
# 38  NaN        NaN              NaN                        NaN       GARVIN
# 39  NaN        NaN              NaN                        NaN        GRADY
# 40  NaN    3.5e+09              NaN                        NaN        GRADY
# 41  NaN    3.5e+09              NaN                        NaN        GRANT
# 42  NaN        NaN              NaN                        NaN       HUGHES
# 43  NaN        NaN              NaN                        NaN        LOGAN
# 44  NaN        NaN              NaN                        NaN  ROGER MILLS
# 45  NaN    3.5e+09              NaN                        NaN  ROGER MILLS
# 46  NaN    3.5e+09              NaN                        NaN  ROGER MILLS
# 47  NaN        NaN              NaN                        NaN  ROGER MILLS
# 48  NaN        NaN              NaN                        NaN  ROGER MILLS
# 49  NaN        NaN              NaN                        NaN     STEPHENS
# 50  NaN    3.5e+09              NaN                        NaN     STEPHENS
# 51  NaN    3.5e+09              NaN                        NaN     STEPHENS
# 63  NaN    3.5e+09              NaN                        NaN        WOODS
# 64  NaN    3.5e+09              NaN                        NaN        WOODS
# 65  NaN        NaN              NaN                        NaN     WOODWARD
# 66  NaN    3.5e+09              NaN                        NaN     WOODWARD
# 67  NaN        NaN              NaN                        NaN          NaN
# 68  NaN        NaN              NaN                        NaN          NaN
# 69  NaN        NaN              NaN                        NaN          NaN
# 70  NaN        NaN              NaN                        NaN          NaN
#
#    Column1 Column10 Column11 Column12 Column13 Column14 Column15 Column16  \
# 1     Acct      LOE      IDC      LWE   Total2      Net  Column3  Column4
# 2   UNT002  1.3e+03        0        0  1.3e+03    3e+02       21       51
# 3   UNT002  9.5e+02        0        0  9.5e+02  4.1e+02       31       57
# 4   UNT002    3e+02        0        0    3e+02       74       20       25
# 5   UNT002  2.9e+02        0        0  2.9e+02       45      9.7       28
# 6   UNT002  3.2e+02        0        0  3.2e+02  1.6e+02       10       25
# 29  CPO035       58        0        0       58    1e+03       20       36
# 30  CPO035       51        0        0       51  4.4e+02       14       33
# 31  CPO035  1.1e+02        0        0  1.1e+02  4.5e+02       27       74
# 32  CPO035       78        0        0       78  1.9e+03       55       51
# 33  MEW001        0        0        0        0       13        0      7.3
# 34  MEW001        0        0        0        0  2.6e+02      9.2       15
# 35  MEW001        0        0        0        0      9.4        0      6.8
# 36  MEW001        0        0        0        0      9.2        0      6.4
# 37  MEW001        0        0        0        0  3.4e+02      9.2      3.2
# 38  PPL002      4.6        0        0      4.6       76      1.4      2.6
# 39  PPL002      4.1        0        0      4.1       65      1.4      2.4
# 40  PPL002      3.4        0        0      3.4       38      1.4      1.8
# 41  PPL002      3.4        0        0      3.4       18      1.4      1.8
# 42  PPL002      4.6        0        0      4.6       20     0.71      2.9
# 43  PPL002        4        0        0        4       49      1.4      2.4
# 44  CEP001  7.7e+02        0        0  7.7e+02  2.7e+03       40    5e+02
# 45  CEP001    4e+02        0        0    4e+02  3.1e+02        0  2.6e+02
# 46  CEP001  6.9e+02        0        0  6.9e+02  1.3e+02        0  4.5e+02
# 47  CEP001  2.3e+02        0        0  2.3e+02      -43        0       75
# 48  CEP002      2.5        0        0      2.5       73      1.5      1.9
# 49  CEP002      2.1        0        0      2.1       42      1.4      1.6
# 50  CEP002      4.1        0        0      4.1       25      1.4      3.3
# 51  CEP002      4.2        0        0      4.2  1.1e+02      2.8      3.4
# 63  CHS008  3.2e+02        0        0  3.2e+02        0        0       80
# 64  CHS008  6.4e+02        0        0  6.4e+02        0      9.9       83
# 65  CHS011      6.8        0        0      6.8      110      1.9       15
# 66  CHS011     0.37        0        0     0.37     0.71        0     0.56
# 67  CHS011       21        0        0       21       85      1.8       32
# 68  CHS011       18        0        0       18       50      1.8       25
# 69  CHS011       17        0        0       17       69      1.8       19
# 70  CHS011       16        0        0       16       89      1.9       20
#
#        Column17 Column18               Column2              Column3  Column4  \
# 1        County    State           Description                 DATE      Gas
# 2        BEAVER       OK              BUTKA 1H  2020-04-01 00:00:00  5.1e+02
# 3        BEAVER       OK              BUTKA 1H  2020-06-01 00:00:00  3.7e+02
# 4        BEAVER       OK              BUTKA 1H  2020-07-01 00:00:00       96
# 5        BEAVER       OK              BUTKA 1H  2020-08-01 00:00:00  1.7e+02
# 6        BEAVER       OK              BUTKA 1H  2020-09-01 00:00:00  1.7e+02
# 29        ELLIS       OK      CROSS 5-16-24 1H  2020-04-01 00:00:00  1.5e+02
# 30        ELLIS       OK      CROSS 5-16-24 1H  2020-05-01 00:00:00  1.2e+02
# 31        ELLIS       OK      CROSS 5-16-24 1H  2020-06-01 00:00:00  1.6e+02
# 32        ELLIS       OK      CROSS 5-16-24 1H  2020-08-01 00:00:00  1.5e+02
# 33        ELLIS       OK       MCLAIN "30" #1H  2020-04-01 00:00:00       14
# 34        ELLIS       OK       MCLAIN "30" #1H  2020-06-01 00:00:00       15
# 35        ELLIS       OK       MCLAIN "30" #1H  2020-07-01 00:00:00       10
# 36        ELLIS       OK       MCLAIN "30" #1H  2020-08-01 00:00:00      9.9
# 37        ELLIS       OK       MCLAIN "30" #1H  2020-09-01 00:00:00      5.8
# 38        ELLIS       OK       JOHN DUNN 1H-30  2020-04-01 00:00:00        0
# 39        ELLIS       OK       JOHN DUNN 1H-30  2020-05-01 00:00:00        0
# 40        ELLIS       OK       JOHN DUNN 1H-30  2020-06-01 00:00:00        0
# 41        ELLIS       OK       JOHN DUNN 1H-30  2020-07-01 00:00:00        0
# 42        ELLIS       OK       JOHN DUNN 1H-30  2020-08-01 00:00:00        0
# 43        ELLIS       OK       JOHN DUNN 1H-30  2020-09-01 00:00:00        0
# 44  ROGER MILLS       OK            ALLEN 1-34  2020-04-01 00:00:00  1.7e+03
# 45  ROGER MILLS       OK            ALLEN 1-34  2020-05-01 00:00:00      740
# 46  ROGER MILLS       OK            ALLEN 1-34  2020-06-01 00:00:00  8.4e+02
# 47  ROGER MILLS       OK            ALLEN 1-34  2020-08-01 00:00:00  1.9e+02
# 48  ROGER MILLS       OK    LORRIE 12-14-25 1H  2020-04-01 00:00:00      7.9
# 49  ROGER MILLS       OK    LORRIE 12-14-25 1H  2020-05-01 00:00:00      5.7
# 50  ROGER MILLS       OK    LORRIE 12-14-25 1H  2020-06-01 00:00:00      7.1
# 51  ROGER MILLS       OK    LORRIE 12-14-25 1H  2020-08-01 00:00:00      9.6
# 63        WOODS       OK             SKYE 1-34  2020-04-01 00:00:00  3.3e+02
# 64        WOODS       OK             SKYE 1-34  2020-06-01 00:00:00  2.3e+02
# 65        WOODS       OK     BELLE 34-29-16 1H  2020-04-01 00:00:00        0
# 66        WOODS       OK     BELLE 34-29-16 1H  2020-05-01 00:00:00        0
# 67        WOODS       OK     BELLE 34-29-16 1H  2020-06-01 00:00:00        0
# 68        WOODS       OK     BELLE 34-29-16 1H  2020-07-01 00:00:00        0
# 69        WOODS       OK     BELLE 34-29-16 1H  2020-08-01 00:00:00        0
# 70        WOODS       OK     BELLE 34-29-16 1H  2020-09-01 00:00:00        0
#
#         Column5  Column6      Column7        Column8  Column9 Comments  \
# 1   Royalty Gas      Oil  Royalty Oil  Severance Tax    Total      NaN
# 2             0  1.2e+03            0        1.1e+02  1.6e+03      NaN
# 3             0  1.1e+03            0             90  1.4e+03      NaN
# 4             0    3e+02            0             22  3.8e+02      NaN
# 5             0  1.8e+02            0             20  3.3e+02      NaN
# 6             0  3.4e+02            0             30  4.8e+02      NaN
# 29            0    1e+03            0             80  1.1e+03      NaN
# 30            0    4e+02            0             35  4.9e+02      NaN
# 31            0  4.4e+02            0             37  5.7e+02      NaN
# 32            0    2e+03            0        1.5e+02    2e+03      NaN
# 33            0        0            0              1       13      NaN
# 34            0  2.6e+02            0             20  2.6e+02      NaN
# 35            0        0            0           0.74      9.4      NaN
# 36            0        0            0           0.71      9.2      NaN
# 37            0  3.6e+02            0             26  3.4e+02      NaN
# 38          9.6        0           77            5.6       81      NaN
# 39          6.9        0           67            4.8       69      NaN
# 40          3.8        0           40            2.9       41      NaN
# 41          2.9        0           20            1.4       21      NaN
# 42          7.8        0           19            1.6       25      NaN
# 43          6.7        0           50            3.7       53      NaN
# 44            0    2e+03            0        2.3e+02  3.4e+03      NaN
# 45            0        0            0             33  7.1e+02      NaN
# 46            0        0            0             24  8.2e+02      NaN
# 47            0        0            0            4.3  1.9e+02      NaN
# 48            0       74            0              6       76      NaN
# 49            0       41            0            3.4       44      NaN
# 50            0       24            0            2.1       29      NaN
# 51            0  1.1e+02            0            8.8  1.1e+02      NaN
# 63            0        0            0             11  3.2e+02      NaN
# 64            0  4.5e+02            0             37  6.4e+02      NaN
# 65           19        0      1.1e+02            8.3  1.2e+02      NaN
# 66          1.1        0            0           0.04      1.1      NaN
# 67           58        0           53            5.1  1.1e+02      NaN
# 68           42        0           28            2.7       67      NaN
# 69           42        0           48            4.5       85      NaN
# 70           42        0           69              6    1e+02      NaN
#
#                FILE NAME                                  FILE TYPE INTEREST  \
# 1      BRUNER 2412 2H-4B                                        NaN      NaN
# 2              BUTKA #1H                                       WELL      NaN
# 3             BUTKA #1HX                                       WELL      NaN
# 4     STATE OF OK B#1-1h                                       WELL      NaN
# 5         BECKHAM COUNTY                                    GENERAL      NaN
# 6          BLAINE COUNTY                                    GENERAL      NaN
# 29           LATTA NO. 6                                       WELL      NaN
# 30          LOUISE #1-30                                       WELL      NaN
# 31       MCLAIN "30" #1H                                   WELL/LOG      NaN
# 32       JOHN DUNN 1H-30                                       Well      NaN
# 33      CROSS 5-16-24 1H                                       WELL      NaN
# 34         TAMZARIAN 1HA                                       WELL      NaN
# 35       GARFIELD COUNTY                                    GENERAL      NaN
# 36       DULICK NO. 32-1                                         WI      NaN
# 37        GREER NO. 32-1                                       ORRI      NaN
# 38         GARVIN COUNTY                                    GENERAL      NaN
# 39      GREGORY NO. 1-27  WELL & LAND & DIVISION ORDER & ASSIGNMENT      NaN
# 40        LYONS NO. 1-27                            WELL/LAND & LOG      NaN
# 41             TOM 23-1H                                       WELL      NaN
# 42         HUGHES COUNTY                                    GENERAL      NaN
# 43          BRANCH NO. 1                                       WELL      NaN
# 44    ROGER MILLS COUNTY                                    GENERAL      NaN
# 45  ALLEN FAMILY #1-34HB                                       WELL      NaN
# 46    GLENDA 9-16-25 #1H                                       WELL      NaN
# 47        PURRIS NO. 1-2                                         WI      NaN
# 48         S17 T16N R25W                                        NaN      NaN
# 49       STEPHENS COUNTY                                    GENERAL      NaN
# 50        CREEL NO. 32-1                                        NaN      NaN
# 51         GLEGHORN 1-32                                       Well      NaN
# 63             SKYE 1-34                                 WELL & LOG      NaN
# 64     BELLE 34-29-16 1H                                       WELL      NaN
# 65       WOODWARD COUNTY                                    GENERAL      NaN
# 66           PEACH NO. 1                                  LAND/WELL      NaN
# 67                   NaN                                        NaN      NaN
# 68                   NaN                                        NaN      NaN
# 69                   NaN                                        NaN      NaN
# 70                   NaN                                        NaN      NaN
#
#                              INTEREST % KEEP KEEP/STORE Mishaun Notes on Well  \
# 1                                   NaN  NaN        NaN                   NaN
# 2                                 0.031  NaN        NaN                   NaN
# 3                                   NaN  NaN        NaN                   NaN
# 4                           WI .0626429  NaN        NaN                   NaN
# 5                                   NaN  NaN        NaN                   NaN
# 6                                   NaN  NaN        NaN                   NaN
# 29                                  NaN  NaN        NaN                   NaN
# 30                                  NaN  NaN        NaN                   NaN
# 31                                0.063  NaN        NaN                   NaN
# 32  ORRI 1/8 for a total royalty of 1/4  NaN        NaN                   NaN
# 33                        0.03762592 WI  NaN        NaN                   NaN
# 34           $1000 per acre/1/5 royalty  NaN        NaN                   NaN
# 35                                  NaN  NaN        NaN                   NaN
# 36                                  NaN  NaN        NaN                   NaN
# 37                     0.0030211000 ORI  NaN        NaN                   NaN
# 38                                  NaN  NaN        NaN                   NaN
# 39                                  NaN  NaN        NaN                   NaN
# 40                          3.642939 WI  NaN        NaN                   NaN
# 41        0.01457304 WI BLM OKNM 124671  NaN        NaN                   NaN
# 42                                  NaN  NaN        NaN                   NaN
# 43                                  NaN  NaN        NaN                   NaN
# 44                                  NaN  NaN        NaN                   NaN
# 45                                  NaN  NaN        NaN                   NaN
# 46                             .0625 WI  NaN        NaN                   NaN
# 47                                  NaN  NaN        NaN                   NaN
# 48                          OKNM 118181  NaN        NaN                   NaN
# 49                                  NaN  NaN        NaN                   NaN
# 50                                  NaN  NaN        NaN                   NaN
# 51                                  NaN  NaN        NaN                   NaN
# 63                                  NaN  NaN        NaN                   NaN
# 64  ORRI 1/8 for a total royalty of 1/4  NaN        NaN                   NaN
# 65                                  NaN  NaN        NaN                   NaN
# 66                                  NaN  NaN        NaN                   NaN
# 67                                  NaN  NaN        NaN                   NaN
# 68                                  NaN  NaN        NaN                   NaN
# 69                                  NaN  NaN        NaN                   NaN
# 70                                  NaN  NaN        NaN                   NaN
#
#    Notes on the Well            OPEN DATE        OPEN MEMO TO OFFICE/FILE  \
# 1                NaN                  NaN                             NaN
# 2                NaN        10/26/2010 km              Plugged 10/12/2011
# 3                NaN        10/12/2012 km                             NaN
# 4                NaN         10/3/2011 km                             NaN
# 5                NaN                  NaN                             NaN
# 6                NaN                  NaN                             NaN
# 29               NaN                  NaN                             NaN
# 30               NaN         3/16/2010 KM         Plano previous operator
# 31               NaN         8/20/2010 KM                             NaN
# 32               NaN           3/29/14 km                             NaN
# 33               NaN          8/9/2016 km                             NaN
# 34               NaN         3/11/2019 km                             NaN
# 35               NaN                  NaN                             NaN
# 36               NaN                  NaN                             NaN
# 37               NaN                  NaN                             NaN
# 38               NaN                  NaN                             NaN
# 39               NaN                  NaN                               7
# 40               NaN                  NaN  Howard Walsh previous operator
# 41               NaN  2011-09-01 00:00:00       Panther previous operator
# 42               NaN                  NaN                             NaN
# 43               NaN                  NaN                             NaN
# 44               NaN                  NaN                             NaN
# 45               NaN    12/4/09 MH (WELL)                             NaN
# 46               NaN          9/7/2010 km                             NaN
# 47               NaN                  NaN                             NaN
# 48               NaN                  NaN                             NaN
# 49               NaN                  NaN                             NaN
# 50               NaN                  NaN                             NaN
# 51               NaN                  NaN                             NaN
# 63               NaN         7/31/2008 MH                             NaN
# 64               NaN        12/29/2011 KM                             NaN
# 65               NaN                  NaN                             NaN
# 66               NaN                  NaN                             NaN
# 67               NaN                  NaN                             NaN
# 68               NaN                  NaN                             NaN
# 69               NaN                  NaN                             NaN
# 70               NaN                  NaN                             NaN
#
#    OPENED                               OPERATOR   OWNER Offsite Storage  \
# 1     NaN                                    NaN     NaN             NaN
# 2     NaN                         UNIT PETROLEUM     R&R             NaN
# 3     NaN                         UNIT PETROLEUM     R&R             NaN
# 4     NaN                         UNIT PETROLEUM     R&R             NaN
# 5     NaN                                    NaN     NaN             NaN
# 6     NaN                                    NaN     NaN             NaN
# 29    NaN                                  AEXCO    MPLP             NaN
# 30    NaN  PRESIDIO PETR. CO/Le Norman Operating     R&R             NaN
# 31    NaN                              MEWBOURNE     R&R             NaN
# 32    NaN  PRESIDIO PETR. CO/Le Norman Operating     R&R             NaN
# 33    NaN                                 APACHE     R&R             NaN
# 34    NaN                              FOURPOINT     R&R             NaN
# 35    NaN                                    NaN     NaN             NaN
# 36    NaN                                    BRG   R & R             NaN
# 37    NaN                              GILLILAND   R & R             NaN
# 38    NaN                                    NaN     NaN             NaN
# 39    NaN                         UNIT PETROLEUM    MPLP             NaN
# 40    NaN                         UNIT PETROLEUM   R & R             NaN
# 41    NaN                              SANDRIDGE     R&R             NaN
# 42    NaN                                    NaN     NaN             NaN
# 43    NaN                           EXXON MOBILE  MINUJA             NaN
# 44    NaN                                    NaN     NaN             NaN
# 45    NaN           PRESIDIO PETR. CO/CORDILLERA     R&R             NaN
# 46    NaN     UNBRIDLED RESOURCES LLC/CHESAPEAKE     R&R             NaN
# 47    NaN                                 SAMSON   R & R             NaN
# 48    NaN                             CHESAPEAKE     R&R             NaN
# 49    NaN                                    NaN     NaN             NaN
# 50    NaN                        GULFPORT ENERGY   R & R             NaN
# 51    NaN                        GULFPORT ENERGY   R & R             NaN
# 63    NaN                             CHESAPEAKE   R & R             NaN
# 64    NaN                    BCE-MACH/CHESAPEAKE     R&R             NaN
# 65    NaN                                    NaN     NaN             NaN
# 66    NaN                             GLB EXPLOR   R & R             NaN
# 67    NaN                                    NaN     NaN             NaN
# 68    NaN                                    NaN     NaN             NaN
# 69    NaN                                    NaN     NaN             NaN
# 70    NaN                                    NaN     NaN             NaN
#
#     Offsite Storage  PARISH                                PROSPECT  \
# 1                NaN    NaN                                     NaN
# 2                NaN    NaN                          S13  T2N  R22E
# 3                NaN    NaN                          S13  T2N  R22E
# 4                NaN    NaN                             S1 T1N R23E
# 5                NaN    NaN                                     NaN
# 6                NaN    NaN                                     NaN
# 29               NaN    NaN                     SECTION 6-T23N-R23W
# 30               NaN    NaN            S30  T17N  R23W; OKNM 118175
# 31               NaN    NaN             S30  T22N  R25W/OKNM 118185
# 32               NaN    NaN              S30 T17N R23W; OKNM 118175
# 33               NaN    NaN                            S5 T16N R24W
# 34               NaN    NaN                 S34-18N-23W; 27-18N-23W
# 35               NaN    NaN                                     NaN
# 36               NaN    NaN           SE/4 NE/4 SECTION 32-T22N-R6W
# 37               NaN    NaN                SW/4 SECTION 32-T22N-R6W
# 38               NaN    NaN                                     NaN
# 39               NaN    NaN                    SECTION 27-T12N-R21W
# 40               NaN    NaN  SECTION 27-T6N-R7W; S. CHICKASHA FIELD
# 41               NaN    NaN                              S23-26N-7W
# 42               NaN    NaN                                     NaN
# 43               NaN    NaN                   NE/4 SECTION 5-12N-4W
# 44               NaN    NaN                                     NaN
# 45               NaN    NaN             SECT 34-17N-25W/OKNM 118182
# 46               NaN    NaN                S9 T16N R25W/OKNM 118181
# 47               NaN    NaN                              S2-12N-26W
# 48               NaN    NaN                                     NaN
# 49               NaN    NaN                                     NaN
# 50               NaN    NaN                                     NaN
# 51               NaN    NaN                                     NaN
# 63               NaN    NaN                      SECTION 34-29N-16W
# 64               NaN    NaN     SECTION 34-29N-16W;     OKNM 120388
# 65               NaN    NaN                                     NaN
# 66               NaN    NaN                               6-22N-19W
# 67               NaN    NaN                                     NaN
# 68               NaN    NaN                                     NaN
# 69               NaN    NaN                                     NaN
# 70               NaN    NaN                                     NaN
#
#    PROSPECT/DESCRIPT.      REMARKS SHRED        ST Sagar's Comments  \
# 1                 NaN          NaN   NaN  Oklahoma              NaN
# 2                 NaN          NaN   NaN  Oklahoma              NaN
# 3                 NaN          NaN   NaN  Oklahoma              NaN
# 4                 NaN  Unified 50%   NaN  Oklahoma              NaN
# 5                 NaN          NaN   NaN  Oklahoma              NaN
# 6                 NaN          NaN   NaN  Oklahoma              NaN
# 29                NaN          NaN   NaN  Oklahoma              NaN
# 30                NaN          NaN   NaN  Oklahoma              NaN
# 31                NaN          NaN   NaN  Oklahoma              NaN
# 32                NaN          NaN   NaN  Oklahoma              NaN
# 33                NaN          NaN   NaN  Oklahoma              NaN
# 34                NaN          NaN   NaN  Oklahoma              NaN
# 35                NaN          NaN   NaN  Oklahoma              NaN
# 36                NaN          NaN   NaN  Oklahoma              NaN
# 37                NaN          NaN   NaN  Oklahoma              NaN
# 38                NaN          NaN   NaN  Oklahoma              NaN
# 39                NaN          NaN   NaN  Oklahoma              NaN
# 40                NaN          NaN   NaN  Oklahoma              NaN
# 41                NaN          NaN   NaN  Oklahoma              NaN
# 42                NaN          NaN   NaN  Oklahoma              NaN
# 43                NaN          NaN   NaN  Oklahoma              NaN
# 44                NaN          NaN   NaN  Oklahoma              NaN
# 45                NaN          NaN   NaN  Oklahoma              NaN
# 46                NaN          NaN   NaN  Oklahoma              NaN
# 47                NaN          NaN   NaN  Oklahoma              NaN
# 48                NaN          NaN   NaN  Oklahoma              NaN
# 49                NaN          NaN   NaN  Oklahoma              NaN
# 50                NaN          NaN   NaN  Oklahoma              NaN
# 51                NaN          NaN   NaN  Oklahoma              NaN
# 63                NaN          NaN   NaN  Oklahoma              NaN
# 64                NaN          NaN   NaN  Oklahoma              NaN
# 65                NaN          NaN   NaN  Oklahoma              NaN
# 66                NaN          NaN   NaN  Oklahoma              NaN
# 67                NaN          NaN   NaN  Oklahoma              NaN
# 68                NaN          NaN   NaN  Oklahoma              NaN
# 69                NaN          NaN   NaN  Oklahoma              NaN
# 70                NaN          NaN   NaN  Oklahoma              NaN
#
#    Sagar’s Comments  Sell (Y/N) Storage Downstairs  Unnamed: 15  Unnamed: 34  \
# 1            Active         NaN                NaN          NaN          NaN
# 2             P&A’d         NaN                NaN          NaN          NaN
# 3            Active         NaN                NaN          NaN          NaN
# 4             P&A’d         NaN                NaN          NaN          NaN
# 5               NaN         NaN                NaN          NaN          NaN
# 6               NaN         NaN                NaN          NaN          NaN
# 29   Well not found         NaN                NaN          NaN          NaN
# 30           Active         NaN                NaN          NaN          NaN
# 31           Active         NaN                NaN          NaN          NaN
# 32           Active         NaN                NaN          NaN          NaN
# 33           Active         NaN                NaN          NaN          NaN
# 34              NaN         NaN                NaN          NaN          NaN
# 35              NaN         NaN                NaN          NaN          NaN
# 36         INACTIVE         NaN                NaN          NaN          NaN
# 37           Active         NaN                NaN          NaN          NaN
# 38              NaN         NaN                NaN          NaN          NaN
# 39   Well not found         NaN                NaN          NaN          NaN
# 40           Active         NaN                NaN          NaN          NaN
# 41           Active         NaN                NaN          NaN          NaN
# 42              NaN         NaN                NaN          NaN          NaN
# 43   Well not found         NaN                NaN          NaN          NaN
# 44              NaN         NaN                NaN          NaN          NaN
# 45           Active         NaN                NaN          NaN          NaN
# 46           Active         NaN                NaN          NaN          NaN
# 47   Well not found         NaN                NaN          NaN          NaN
# 48              NaN         NaN                NaN          NaN          NaN
# 49              NaN         NaN                NaN          NaN          NaN
# 50           Active         NaN                NaN          NaN          NaN
# 51           Active         NaN                NaN          NaN          NaN
# 63           ACTIVE         NaN                NaN          NaN          NaN
# 64           ACTIVE         NaN                NaN          NaN          NaN
# 65              NaN         NaN                NaN          NaN          NaN
# 66            P&A’d         NaN                NaN          NaN          NaN
# 67              NaN         NaN                NaN          NaN          NaN
# 68              NaN         NaN                NaN          NaN          NaN
# 69              NaN         NaN                NaN          NaN          NaN
# 70              NaN         NaN                NaN          NaN          NaN
#
#    Unnamed: 35      Unnamed: 36 Unnamed: 37  Unnamed: 38  Unnamed: 39  \
# 1          NaN              NaN         NaT          NaN          NaN
# 2          NaN              NaN         NaT          NaN          NaN
# 3          NaN              NaN         NaT          NaN          NaN
# 4          NaN              NaN         NaT          NaN          NaN
# 5          NaN              NaN         NaT          NaN          NaN
# 6          NaN              NaN         NaT          NaN          NaN
# 29         NaN              NaN         NaT          NaN          NaN
# 30         NaN              NaN         NaT          NaN          NaN
# 31         NaN              NaN         NaT          NaN          NaN
# 32         NaN              NaN         NaT          NaN          NaN
# 33         NaN              NaN         NaT          NaN          NaN
# 34         NaN              NaN         NaT          NaN          NaN
# 35      WNG001       GREER 32-1  2020-08-01         0.00        29.73
# 36         NaN              NaN         NaT          NaN          NaN
# 37         NaN              NaN         NaT          NaN          NaN
# 38         NaN              NaN         NaT          NaN          NaN
# 39         NaN              NaN         NaT          NaN          NaN
# 40         NaN              NaN         NaT          NaN          NaN
# 41         NaN              NaN         NaT          NaN          NaN
# 42         NaN              NaN         NaT          NaN          NaN
# 43         NaN              NaN         NaT          NaN          NaN
# 44         NaN              NaN         NaT          NaN          NaN
# 45         NaN              NaN         NaT          NaN          NaN
# 46         NaN              NaN         NaT          NaN          NaN
# 47         NaN              NaN         NaT          NaN          NaN
# 48         NaN              NaN         NaT          NaN          NaN
# 49      CHS001       CREEL 32-1  2020-04-01        19.62         0.00
# 50      CHS001       CREEL 32-1  2020-06-01        41.06         0.00
# 51      CHS002    GLEGHORN 1-32  2020-04-01       223.38         0.00
# 63         NaN              NaN         NaT          NaN          NaN
# 64         NaN              NaN         NaT          NaN          NaN
# 65         NaN              NaN         NaT          NaN          NaN
# 66         NaN              NaN         NaT          NaN          NaN
# 67         NaN              NaN         NaT          NaN          NaN
# 68         NaN              NaN         NaT          NaN          NaN
# 69         NaN              NaN         NaT          NaN          NaN
# 70         NaN              NaN         NaT          NaN          NaN
#
#     Unnamed: 40  Unnamed: 41  Unnamed: 42  Unnamed: 43  Unnamed: 44  \
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN          NaN
# 30          NaN          NaN          NaN          NaN          NaN
# 31          NaN          NaN          NaN          NaN          NaN
# 32          NaN          NaN          NaN          NaN          NaN
# 33          NaN          NaN          NaN          NaN          NaN
# 34          NaN          NaN          NaN          NaN          NaN
# 35          0.0          0.0         3.63        26.10         0.00
# 36          NaN          NaN          NaN          NaN          NaN
# 37          NaN          NaN          NaN          NaN          NaN
# 38          NaN          NaN          NaN          NaN          NaN
# 39          NaN          NaN          NaN          NaN          NaN
# 40          NaN          NaN          NaN          NaN          NaN
# 41          NaN          NaN          NaN          NaN          NaN
# 42          NaN          NaN          NaN          NaN          NaN
# 43          NaN          NaN          NaN          NaN          NaN
# 44          NaN          NaN          NaN          NaN          NaN
# 45          NaN          NaN          NaN          NaN          NaN
# 46          NaN          NaN          NaN          NaN          NaN
# 47          NaN          NaN          NaN          NaN          NaN
# 48          NaN          NaN          NaN          NaN          NaN
# 49          0.0          0.0         0.95        18.67        59.07
# 50          0.0          0.0         1.97        39.09        79.63
# 51          0.0          0.0        10.51       212.87       149.28
# 63          NaN          NaN          NaN          NaN          NaN
# 64          NaN          NaN          NaN          NaN          NaN
# 65          NaN          NaN          NaN          NaN          NaN
# 66          NaN          NaN          NaN          NaN          NaN
# 67          NaN          NaN          NaN          NaN          NaN
# 68          NaN          NaN          NaN          NaN          NaN
# 69          NaN          NaN          NaN          NaN          NaN
# 70          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 45  Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  \
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN          NaN
# 30          NaN          NaN          NaN          NaN          NaN
# 31          NaN          NaN          NaN          NaN          NaN
# 32          NaN          NaN          NaN          NaN          NaN
# 33          NaN          NaN          NaN          NaN          NaN
# 34          NaN          NaN          NaN          NaN          NaN
# 35          0.0          0.0         0.00        26.10          0.0
# 36          NaN          NaN          NaN          NaN          NaN
# 37          NaN          NaN          NaN          NaN          NaN
# 38          NaN          NaN          NaN          NaN          NaN
# 39          NaN          NaN          NaN          NaN          NaN
# 40          NaN          NaN          NaN          NaN          NaN
# 41          NaN          NaN          NaN          NaN          NaN
# 42          NaN          NaN          NaN          NaN          NaN
# 43          NaN          NaN          NaN          NaN          NaN
# 44          NaN          NaN          NaN          NaN          NaN
# 45          NaN          NaN          NaN          NaN          NaN
# 46          NaN          NaN          NaN          NaN          NaN
# 47          NaN          NaN          NaN          NaN          NaN
# 48          NaN          NaN          NaN          NaN          NaN
# 49          0.0          0.0        59.07       -40.40          0.0
# 50          0.0          0.0        79.63       -40.54          0.0
# 51          0.0          0.0       149.28        63.59          0.0
# 63          NaN          NaN          NaN          NaN          NaN
# 64          NaN          NaN          NaN          NaN          NaN
# 65          NaN          NaN          NaN          NaN          NaN
# 66          NaN          NaN          NaN          NaN          NaN
# 67          NaN          NaN          NaN          NaN          NaN
# 68          NaN          NaN          NaN          NaN          NaN
# 69          NaN          NaN          NaN          NaN          NaN
# 70          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 50 Unnamed: 51 Unnamed: 52
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN
# 5           NaN         NaN         NaN
# 6           NaN         NaN         NaN
# 29          NaN         NaN         NaN
# 30          NaN         NaN         NaN
# 31          NaN         NaN         NaN
# 32          NaN         NaN         NaN
# 33          NaN         NaN         NaN
# 34          NaN         NaN         NaN
# 35        21.64    GARFIELD          OK
# 36          NaN         NaN         NaN
# 37          NaN         NaN         NaN
# 38          NaN         NaN         NaN
# 39          NaN         NaN         NaN
# 40          NaN         NaN         NaN
# 41          NaN         NaN         NaN
# 42          NaN         NaN         NaN
# 43          NaN         NaN         NaN
# 44          NaN         NaN         NaN
# 45          NaN         NaN         NaN
# 46          NaN         NaN         NaN
# 47          NaN         NaN         NaN
# 48          NaN         NaN         NaN
# 49         8.53    STEPHENS          OK
# 50        22.41    STEPHENS          OK
# 51        94.29    STEPHENS          OK
# 63          NaN         NaN         NaN
# 64          NaN         NaN         NaN
# 65          NaN         NaN         NaN
# 66          NaN         NaN         NaN
# 67          NaN         NaN         NaN
# 68          NaN         NaN         NaN
# 69          NaN         NaN         NaN
# 70          NaN         NaN         NaN

# %%
mergedDF.count()
# Out:
# API                              3
# API Number                     328
# Anish’s Comments               123
# CLOSED MEMO TO OFFICE/FILE      11
# COUNTY                        1342
# Column1                         37
# Column10                        37
# Column11                        37
# Column12                        37
# Column13                        37
# Column14                        37
# Column15                        37
# Column16                        37
# Column17                        37
# Column18                        37
# Column2                         37
# Column3                         37
# Column4                         37
# Column5                         37
# Column6                         37
# Column7                         37
# Column8                         37
# Column9                         37
# Comments                        85
# FILE NAME                     1404
# FILE TYPE                     1345
# INTEREST                       178
# INTEREST %                     107
# KEEP                            21
# KEEP/STORE                     147
#                               ...
# PARISH                          57
# PROSPECT                       671
# PROSPECT/DESCRIPT.              21
# REMARKS                        307
# SHRED                           16
# ST                            1421
# Sagar's Comments                 8
# Sagar’s Comments                85
# Sell (Y/N)                       0
# Storage Downstairs               2
# Unnamed: 15                      0
# Unnamed: 34                      0
# Unnamed: 35                      9
# Unnamed: 36                      9
# Unnamed: 37                      9
# Unnamed: 38                      9
# Unnamed: 39                      9
# Unnamed: 40                      9
# Unnamed: 41                      9
# Unnamed: 42                      9
# Unnamed: 43                      9
# Unnamed: 44                      9
# Unnamed: 45                      9
# Unnamed: 46                      9
# Unnamed: 47                      9
# Unnamed: 48                      9
# Unnamed: 49                      9
# Unnamed: 50                      9
# Unnamed: 51                      9
# Unnamed: 52                      9
# Length: 69, dtype: int64

# %% [markdown]
# ### Defining function to handle dropping multiple columns

# %%
def ColumnDropbyName(colname, *dropnames):
    '''
        This function expect a column names to be passed in to be dropped under args dropnames
        The colname will be the column in a dataframe that dropnames will be compared to for partial match
    '''
    for dropname in dropnames:
        if dropname.lower() in colname.lower():
            return True
        
    return False

#test function
ColumnDropbyName("Column1", "Column")
ColumnDropbyName("Unnamed", "Unna")
ColumnDropbyName("API", "high")
# Out:
# True
# True
# False

# %%
#applying function to get column names to drop
colsToDrop = (list(filter(lambda x: ColumnDropbyName(x, 'Column', 'Unnamed'), mergedDF.columns)))
colsToDrop
# Out:
# ['Column1',
#  'Column10',
#  'Column11',
#  'Column12',
#  'Column13',
#  'Column14',
#  'Column15',
#  'Column16',
#  'Column17',
#  'Column18',
#  'Column2',
#  'Column3',
#  'Column4',
#  'Column5',
#  'Column6',
#  'Column7',
#  'Column8',
#  'Column9',
#  'Unnamed: 15',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52']

# %% [markdown]
# ### Dropping columns with function found column names and manually inspected column names

# %%
pd.options.display.max_columns = 100
mergedDF.drop(columns = colsToDrop, inplace = True)

# %%
#dropping column with no nonnull values in offsite storage 
mergedDF.drop(columns = "Offsite Storage ", inplace = True)

# %%
mergedDF.head()
# Out:
#    API  API Number        Anish’s Comments CLOSED MEMO TO OFFICE/FILE  \
# 0  NaN  4212300017                  Active                        NaN
# 1  NaN         NaN          Well not found                        NaN
# 2  NaN         NaN          Well not found                        NaN
# 3  NaN  4208932360  Inactive since 12/2011                        NaN
# 4  NaN  4224532445                  Active                        NaN
#
#       COUNTY Comments                   FILE NAME          FILE TYPE INTEREST  \
# 0     DEWITT      NaN                HENSON GU #1               WELL      NaN
# 1     DEWITT      NaN               HENSON GU #2H               WELL      NaN
# 2     DEWITT      NaN               HENSON GU #3H               ORRI      NaN
# 3   COLORADO      NaN                  LUCKETT #1  LAND / WELL / LOG      NaN
# 4  JEFFERSON      NaN  PETKOVSEK, LOLIA. ET AL #1               WELL      NaN
#
#   INTEREST % KEEP KEEP/STORE    Mishaun Notes on Well Notes on the Well  \
# 0        NaN  NaN       keep  Already decided to keep               NaN
# 1        NaN  NaN       keep  Already decided to keep               NaN
# 2        NaN  NaN       keep  Already decided to keep               NaN
# 3        NaN  NaN        NaN                      NaN               NaN
# 4        NaN  NaN        NaN                      NaN               NaN
#
#      OPEN DATE OPEN MEMO TO OFFICE/FILE OPENED  \
# 0          NaN                      NaN    NaN
# 1          NaN                      NaN    NaN
# 2          NaN                      NaN    NaN
# 3          NaN                      NaN    NaN
# 4  7/1/2012 km   Aspect Former Operator    NaN
#
#                                             OPERATOR  OWNER Offsite Storage  \
# 0                  ABRAXAS (Current Operator: Atlas)   MPLP             NaN
# 1                                            ABRAXAS   MPLP             NaN
# 2                                            ABRAXAS   MPLP             NaN
# 3  ACOCK-ANAQUA (Current Operator: Magnum Producing)  R & R             NaN
# 4                    ALEGRE ENERGY (Current Op: S&S)   MPLP             NaN
#
#   PARISH PROSPECT PROSPECT/DESCRIPT.                            REMARKS SHRED  \
# 0    NaN      NaN                NaN                                NaN   NaN
# 1    NaN      NaN                NaN                                NaN   NaN
# 2    NaN      NaN                NaN                                NaN   NaN
# 3    NaN      NaN                NaN  OPERATED BY MAGNUM EFFECTIVE 7/09   NaN
# 4    NaN      NaN                NaN                                NaN   NaN
#
#       ST Sagar's Comments Sagar’s Comments  Sell (Y/N) Storage Downstairs
# 0  Texas              NaN              NaN         NaN                NaN
# 1  Texas              NaN              NaN         NaN                NaN
# 2  Texas              NaN              NaN         NaN                NaN
# 3  Texas              NaN              NaN         NaN                NaN
# 4  Texas              NaN              NaN         NaN                NaN

# %%
mergedDF.to_excel('Test_merges/testMerge2.xlsx') # Saving file for manual Inspection

# %%
#inspecting columns and how many nonnull values they have
mergedDF.count()
# Out:
# API                              3
# API Number                     328
# Anish’s Comments               123
# CLOSED MEMO TO OFFICE/FILE      11
# COUNTY                        1342
# Comments                        85
# FILE NAME                     1404
# FILE TYPE                     1345
# INTEREST                       178
# INTEREST %                     107
# KEEP                            21
# KEEP/STORE                     147
# Mishaun Notes on Well          178
# Notes on the Well               55
# OPEN DATE                      470
# OPEN MEMO TO OFFICE/FILE        51
# OPENED                          29
# OPERATOR                      1237
# OWNER                         1330
# Offsite Storage                 11
# PARISH                          57
# PROSPECT                       671
# PROSPECT/DESCRIPT.              21
# REMARKS                        307
# SHRED                           16
# ST                            1421
# Sagar's Comments                 8
# Sagar’s Comments                85
# Sell (Y/N)                       0
# Storage Downstairs               2
# dtype: int64

# %% [markdown]
# ### Dropping blank rows after manually inspecting table in excel

# %%
mergedDF.dropna(how='all').shape
mergedDF.shape

#dropping empty rows
mergedDF.dropna(how="all", inplace = True)
# Out:
# (1421, 30)
# (1421, 30)

# %% [markdown]
# ### Cleaning up column names that are troublesome due to apostrophies and duplicates

# %%
mergedDF.rename(columns = {"Sagar's Comments": "Sagar First Duplicate"}, inplace = True)

# %%
mergedDF.rename(columns = {"Sagar’s Comments": "Sagar Second Duplicate"}, inplace = True)

# %%
mergedDF.head()
# Out:
#    API  API Number        Anish’s Comments CLOSED MEMO TO OFFICE/FILE  \
# 0  NaN  4212300017                  Active                        NaN
# 1  NaN         NaN          Well not found                        NaN
# 2  NaN         NaN          Well not found                        NaN
# 3  NaN  4208932360  Inactive since 12/2011                        NaN
# 4  NaN  4224532445                  Active                        NaN
#
#       COUNTY Comments                   FILE NAME          FILE TYPE INTEREST  \
# 0     DEWITT      NaN                HENSON GU #1               WELL      NaN
# 1     DEWITT      NaN               HENSON GU #2H               WELL      NaN
# 2     DEWITT      NaN               HENSON GU #3H               ORRI      NaN
# 3   COLORADO      NaN                  LUCKETT #1  LAND / WELL / LOG      NaN
# 4  JEFFERSON      NaN  PETKOVSEK, LOLIA. ET AL #1               WELL      NaN
#
#   INTEREST % KEEP KEEP/STORE    Mishaun Notes on Well Notes on the Well  \
# 0        NaN  NaN       keep  Already decided to keep               NaN
# 1        NaN  NaN       keep  Already decided to keep               NaN
# 2        NaN  NaN       keep  Already decided to keep               NaN
# 3        NaN  NaN        NaN                      NaN               NaN
# 4        NaN  NaN        NaN                      NaN               NaN
#
#      OPEN DATE OPEN MEMO TO OFFICE/FILE OPENED  \
# 0          NaN                      NaN    NaN
# 1          NaN                      NaN    NaN
# 2          NaN                      NaN    NaN
# 3          NaN                      NaN    NaN
# 4  7/1/2012 km   Aspect Former Operator    NaN
#
#                                             OPERATOR  OWNER Offsite Storage  \
# 0                  ABRAXAS (Current Operator: Atlas)   MPLP             NaN
# 1                                            ABRAXAS   MPLP             NaN
# 2                                            ABRAXAS   MPLP             NaN
# 3  ACOCK-ANAQUA (Current Operator: Magnum Producing)  R & R             NaN
# 4                    ALEGRE ENERGY (Current Op: S&S)   MPLP             NaN
#
#   PARISH PROSPECT PROSPECT/DESCRIPT.                            REMARKS SHRED  \
# 0    NaN      NaN                NaN                                NaN   NaN
# 1    NaN      NaN                NaN                                NaN   NaN
# 2    NaN      NaN                NaN                                NaN   NaN
# 3    NaN      NaN                NaN  OPERATED BY MAGNUM EFFECTIVE 7/09   NaN
# 4    NaN      NaN                NaN                                NaN   NaN
#
#       ST Sagar First Duplicate Sagar Second Duplicate  Sell (Y/N)  \
# 0  Texas                   NaN                    NaN         NaN
# 1  Texas                   NaN                    NaN         NaN
# 2  Texas                   NaN                    NaN         NaN
# 3  Texas                   NaN                    NaN         NaN
# 4  Texas                   NaN                    NaN         NaN
#
#   Storage Downstairs
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# ### Saving cleaned up columns and column names to file

# %%
#this file will be a good place to reopen dataframe for merging identical fields
mergedDF.to_excel('Test_merges/Checkpoint.xlsx', index = False)

# %% [markdown]
# ## Merging Identical Fields with Different Column Names

# %%
#read in file from checkpoint
mergedDF = pd.read_excel("Test_merges/Checkpoint.xlsx")
mergedDF.head()
# Out:
#    API  API Number        Anish’s Comments CLOSED MEMO TO OFFICE/FILE  \
# 0  NaN  4212300017                  Active                        NaN
# 1  NaN         NaN          Well not found                        NaN
# 2  NaN         NaN          Well not found                        NaN
# 3  NaN  4208932360  Inactive since 12/2011                        NaN
# 4  NaN  4224532445                  Active                        NaN
#
#       COUNTY Comments                   FILE NAME          FILE TYPE INTEREST  \
# 0     DEWITT      NaN                HENSON GU #1               WELL      NaN
# 1     DEWITT      NaN               HENSON GU #2H               WELL      NaN
# 2     DEWITT      NaN               HENSON GU #3H               ORRI      NaN
# 3   COLORADO      NaN                  LUCKETT #1  LAND / WELL / LOG      NaN
# 4  JEFFERSON      NaN  PETKOVSEK, LOLIA. ET AL #1               WELL      NaN
#
#   INTEREST % KEEP KEEP/STORE    Mishaun Notes on Well Notes on the Well  \
# 0        NaN  NaN       keep  Already decided to keep               NaN
# 1        NaN  NaN       keep  Already decided to keep               NaN
# 2        NaN  NaN       keep  Already decided to keep               NaN
# 3        NaN  NaN        NaN                      NaN               NaN
# 4        NaN  NaN        NaN                      NaN               NaN
#
#      OPEN DATE OPEN MEMO TO OFFICE/FILE OPENED  \
# 0          NaN                      NaN    NaN
# 1          NaN                      NaN    NaN
# 2          NaN                      NaN    NaN
# 3          NaN                      NaN    NaN
# 4  7/1/2012 km   Aspect Former Operator    NaN
#
#                                             OPERATOR  OWNER Offsite Storage  \
# 0                  ABRAXAS (Current Operator: Atlas)   MPLP             NaN
# 1                                            ABRAXAS   MPLP             NaN
# 2                                            ABRAXAS   MPLP             NaN
# 3  ACOCK-ANAQUA (Current Operator: Magnum Producing)  R & R             NaN
# 4                    ALEGRE ENERGY (Current Op: S&S)   MPLP             NaN
#
#   PARISH PROSPECT PROSPECT/DESCRIPT.                            REMARKS SHRED  \
# 0    NaN      NaN                NaN                                NaN   NaN
# 1    NaN      NaN                NaN                                NaN   NaN
# 2    NaN      NaN                NaN                                NaN   NaN
# 3    NaN      NaN                NaN  OPERATED BY MAGNUM EFFECTIVE 7/09   NaN
# 4    NaN      NaN                NaN                                NaN   NaN
#
#       ST Sagar First Duplicate Sagar Second Duplicate  Sell (Y/N)  \
# 0  Texas                   NaN                    NaN         NaN
# 1  Texas                   NaN                    NaN         NaN
# 2  Texas                   NaN                    NaN         NaN
# 3  Texas                   NaN                    NaN         NaN
# 4  Texas                   NaN                    NaN         NaN
#
#   Storage Downstairs
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# ### API Merging

# %%
#filling in blank strings for nulls, converting to strings, and concatenating together 
mergedDF["API/UWI"] = mergedDF["API"].fillna(value='').astype(str) + mergedDF["API Number"].fillna('').astype(str)
mergedDF["API/UWI"] = mergedDF["API/UWI"].apply(lambda x: x.split('.')[0]) #removing decimals from string, created from export to excel

# %%
mergedDF.drop(columns=["API", "API Number"], inplace = True)

# %% [markdown]
# ## Merging Notes, Interest Fields, Keep/NotKeep

# %%
def MergeColsbyName(dataframe, *columnstomerge, mergedColName):
    
    '''
    Columns to merge must be passed in as a list
    
    This function will take in a pandas dataframe, columns to merge, and an ouput column name after the merge
    It will then merge the columns together by concatenating values as text
    If there are multiple columns with nonnull values, the values will be concatenated with a pipe | symbol
    If there is just 1 column with non null values, columns will be concatenated with a blank space
    The columns that were merged will then be dropped from the dataframe and the dataframe will be returned
    
    '''

    columnstomerge = columnstomerge[0]
    
    #reference to how to use apply on multiple columns https://stackoverflow.com/questions/39291499/how-to-concatenate-multiple-column-values-into-a-single-column-in-panda-datafram
    # This lambda function will join columns that are selected together 
    # conditional statements direct that if there is only 1 non null field, merge with blank string ->
    # else, if there are more than 1 non null field, merge values together with a pipe | symbol
    dataframe[mergedColName] = dataframe[columnstomerge].apply(lambda row: ''.join(row.fillna('').values.astype(str)) if row.count()<2 else ' | '.join(row.fillna('').values.astype(str)), axis=1)
    
    #dropping columns after merging
    dataframe.drop(columns = columnstomerge, inplace = True)
    
    return dataframe

# %% [markdown]
# ### Create dictionary manually to decide columns to be merged based on similarity - Create Output Names

# %%
#dictionary to hold info on merging columns and their output column name
ColsMergeDict = {
    "INTEREST (WI,ORRI, ETC)": ["INTEREST", "INTEREST %"], 
    "KEEP/SHRED": ["KEEP","KEEP/STORE", "SHRED"], 
    "COUNTY/PARISH": ["COUNTY", "PARISH"], 
    "Sagar": ["Sagar First Duplicate", "Sagar Second Duplicate"], #merging sagar's comments first then merging at end, it will work due to the choronology of the loop
    "STORAGE LOCATION": ["Storage Downstairs", "Offsite Storage"], 
    "DATE OPENED": ["OPENED", "OPEN DATE"],
    "COMMENTS/NOTES": ["Anish’s Comments", "Mishaun Notes on Well", "Notes on the Well", "Comments", "REMARKS", "Sagar"] 
}

# %% [markdown]
# ### Executing function, looping through all items in dictionary

# %%
for outputcol, mergecols in ColsMergeDict.items():
    mergedDF = MergeColsbyName(mergedDF, mergecols, mergedColName=outputcol)

# %%
mergedDF.columns
# Out:
# Index(['CLOSED MEMO TO OFFICE/FILE', 'FILE NAME', 'FILE TYPE',
#        'OPEN MEMO TO OFFICE/FILE', 'OPERATOR', 'OWNER', 'PROSPECT',
#        'PROSPECT/DESCRIPT.', 'ST', 'Sell (Y/N)', 'API/UWI',
#        'INTEREST (WI,ORRI, ETC)', 'KEEP/SHRED', 'COUNTY/PARISH',
#        'STORAGE LOCATION', 'DATE OPENED', 'COMMENTS/NOTES'],
#       dtype='object')

# %% [markdown]
# ## Cleaning Text in Comments Section with Regex

# %%
import re

# %%
sampleString = mergedDF["COMMENTS/NOTES"].iloc[0]
sampleString
# Out:
# 'Active | Already decided to keep |  |  |  | '

# %%
pattern = '  \|'

# %%
re.sub(pattern, '', sampleString).rstrip()
# Out:
# 'Active | Already decided to keep |'

# %%
mergedDF["COMMENTS/NOTES"] = mergedDF["COMMENTS/NOTES"].apply(lambda x: re.sub(pattern, '', x).rstrip())

# %%
mergedDF.head(5)
# Out:
#   CLOSED MEMO TO OFFICE/FILE                   FILE NAME          FILE TYPE  \
# 0                        NaN                HENSON GU #1               WELL
# 1                        NaN               HENSON GU #2H               WELL
# 2                        NaN               HENSON GU #3H               ORRI
# 3                        NaN                  LUCKETT #1  LAND / WELL / LOG
# 4                        NaN  PETKOVSEK, LOLIA. ET AL #1               WELL
#
#   OPEN MEMO TO OFFICE/FILE                                           OPERATOR  \
# 0                      NaN                  ABRAXAS (Current Operator: Atlas)
# 1                      NaN                                            ABRAXAS
# 2                      NaN                                            ABRAXAS
# 3                      NaN  ACOCK-ANAQUA (Current Operator: Magnum Producing)
# 4   Aspect Former Operator                    ALEGRE ENERGY (Current Op: S&S)
#
#    OWNER PROSPECT PROSPECT/DESCRIPT.     ST  Sell (Y/N)     API/UWI  \
# 0   MPLP      NaN                NaN  Texas         NaN  4212300017
# 1   MPLP      NaN                NaN  Texas         NaN
# 2   MPLP      NaN                NaN  Texas         NaN
# 3  R & R      NaN                NaN  Texas         NaN  4208932360
# 4   MPLP      NaN                NaN  Texas         NaN  4224532445
#
#   INTEREST (WI,ORRI, ETC) KEEP/SHRED COUNTY/PARISH STORAGE LOCATION  \
# 0                               keep        DEWITT
# 1                               keep        DEWITT
# 2                               keep        DEWITT
# 3                                         COLORADO
# 4                                        JEFFERSON
#
#    DATE OPENED                                     COMMENTS/NOTES
# 0                              Active | Already decided to keep |
# 1                      Well not found | Already decided to keep |
# 2                      Well not found | Already decided to keep |
# 3               Inactive since 12/2011 | OPERATED BY MAGNUM EF...
# 4  7/1/2012 km                                           Active |

# %% [markdown]
# ## Reordering Data Table and Exporting

# %%
mergedDF.count()
# Out:
# CLOSED MEMO TO OFFICE/FILE      11
# FILE NAME                     1404
# FILE TYPE                     1345
# OPEN MEMO TO OFFICE/FILE        51
# OPERATOR                      1237
# OWNER                         1330
# PROSPECT                       671
# PROSPECT/DESCRIPT.              21
# ST                            1421
# Sell (Y/N)                       0
# API/UWI                       1421
# INTEREST (WI,ORRI, ETC)       1421
# KEEP/SHRED                    1421
# COUNTY/PARISH                 1421
# STORAGE LOCATION              1421
# DATE OPENED                   1421
# COMMENTS/NOTES                1421
# dtype: int64

# %%
columnOrder = [
    'API/UWI',
    'FILE NAME', 
    'FILE TYPE', 
    'OPERATOR',
    'COUNTY/PARISH',
    'ST',
    'PROSPECT',
    'PROSPECT/DESCRIPT.', 
    'COMMENTS/NOTES',
    'KEEP/SHRED',
    'Sell (Y/N)',
    'INTEREST (WI,ORRI, ETC)',
    'OWNER', 
    'OPEN MEMO TO OFFICE/FILE',  
    'CLOSED MEMO TO OFFICE/FILE', 
    'STORAGE LOCATION', 
]

# %%
mergedDF = mergedDF[columnOrder]
mergedDF.head()
# Out:
#       API/UWI                   FILE NAME          FILE TYPE  \
# 0  4212300017                HENSON GU #1               WELL
# 1                           HENSON GU #2H               WELL
# 2                           HENSON GU #3H               ORRI
# 3  4208932360                  LUCKETT #1  LAND / WELL / LOG
# 4  4224532445  PETKOVSEK, LOLIA. ET AL #1               WELL
#
#                                             OPERATOR COUNTY/PARISH     ST  \
# 0                  ABRAXAS (Current Operator: Atlas)        DEWITT  Texas
# 1                                            ABRAXAS        DEWITT  Texas
# 2                                            ABRAXAS        DEWITT  Texas
# 3  ACOCK-ANAQUA (Current Operator: Magnum Producing)      COLORADO  Texas
# 4                    ALEGRE ENERGY (Current Op: S&S)     JEFFERSON  Texas
#
#   PROSPECT PROSPECT/DESCRIPT.  \
# 0      NaN                NaN
# 1      NaN                NaN
# 2      NaN                NaN
# 3      NaN                NaN
# 4      NaN                NaN
#
#                                       COMMENTS/NOTES KEEP/SHRED  Sell (Y/N)  \
# 0                 Active | Already decided to keep |       keep         NaN
# 1         Well not found | Already decided to keep |       keep         NaN
# 2         Well not found | Already decided to keep |       keep         NaN
# 3  Inactive since 12/2011 | OPERATED BY MAGNUM EF...                    NaN
# 4                                           Active |                    NaN
#
#   INTEREST (WI,ORRI, ETC)  OWNER OPEN MEMO TO OFFICE/FILE  \
# 0                           MPLP                      NaN
# 1                           MPLP                      NaN
# 2                           MPLP                      NaN
# 3                          R & R                      NaN
# 4                           MPLP   Aspect Former Operator
#
#   CLOSED MEMO TO OFFICE/FILE STORAGE LOCATION
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
mergedDF.to_excel("Cleaned & Merged OBO List.xlsx", index = False, sheet_name="NonOp Master")
